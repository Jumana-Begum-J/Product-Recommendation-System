# %% [markdown]
# 1. Install Scikit-Surprise Library and Import Libraries

# %%
# !pip install scikit-surprise
import numpy as np  
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from collections import defaultdict
from surprise import KNNWithMeans
from surprise import SVD, SVDpp
from surprise import KNNBaseline
from surprise import KNNBasic
from surprise import KNNWithZScore
from surprise import BaselineOnly
from surprise import Dataset
from surprise import Reader
from surprise import accuracy
from surprise.model_selection import train_test_split
from surprise.model_selection import cross_validate
from surprise.model_selection import KFold
from surprise.model_selection import GridSearchCV

import time
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-surprise
#   Downloading scikit-surprise-1.1.3.tar.gz (771 kB)
#      |████████████████████████████████| 771 kB 33.1 MB/s
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-surprise) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from scikit-surprise) (1.21.6)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.8/dist-packages (from scikit-surprise) (1.7.3)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp38-cp38-linux_x86_64.whl size=2626488 sha256=2e8b1b1a26d83097360e848f5ff19657e464d4b01c5a7fa56363f4d201a95fa7
#   Stored in directory: /root/.cache/pip/wheels/af/db/86/2c18183a80ba05da35bf0fb7417aac5cddbd93bcb1b92fd3ea
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.3

# %% [markdown]
# 2. Connect to GDrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 3. Load Dataset

# %%
start_time = time.time()

df = pd.read_csv("/content/drive/MyDrive/SNAProject/ratings_Electronics.csv", names=["userId", "productId", "rating", "timestamp"])  
print(df.head()) 

computational_time = time.time() - start_time
print('Done in %0.3fs' %(computational_time))
# Out:
#            userId   productId  rating   timestamp
# 0   AKM1MP6P0OYPR  0132793040     5.0  1365811200
# 1  A2CX7LUOHB2NDG  0321732944     5.0  1341100800
# 2  A2NWSAGRHCP8N5  0439886341     1.0  1367193600
# 3  A2WNBOD3WNDNKT  0439886341     3.0  1374451200
# 4  A1GI0U4ZRJA8WN  0439886341     1.0  1334707200
# Done in 11.317s

# %% [markdown]
# 4. Print number of Rows and Columns in the dataset

# %%
rows_count, columns_count = df.shape
print('Total Number of rows :', rows_count)
print('Total Number of columns :', columns_count)
# Out:
# Total Number of rows : 7824482
# Total Number of columns : 4

# %% [markdown]
# 5. Print number of unique users and products in the dataset

# %%
unique_userId = df['userId'].nunique()
unique_productId = df['productId'].nunique()
print('Total number of unique Users    : ', unique_userId)
print('Total number of unique Products : ', unique_productId)
# Out:
# Total number of unique Users    :  4201696
# Total number of unique Products :  476002

# %% [markdown]
# 6. Check if any null values are present in the dataset

# %%
df.isna().any()
# Out:
# userId       False
# productId    False
# rating       False
# timestamp    False
# dtype: bool

# %% [markdown]
# 7. Drop Timestamp Column

# %%
df = df.drop(['timestamp'], axis=1)
df.head()
# Out:
#            userId   productId  rating
# 0   AKM1MP6P0OYPR  0132793040     5.0
# 1  A2CX7LUOHB2NDG  0321732944     5.0
# 2  A2NWSAGRHCP8N5  0439886341     1.0
# 3  A2WNBOD3WNDNKT  0439886341     3.0
# 4  A1GI0U4ZRJA8WN  0439886341     1.0

# %% [markdown]
# 8. Select Users who have given more than 50 ratings

# %%
users_counts = df['userId'].value_counts().rename('users_counts')
users_data   = df.merge(users_counts.to_frame(),
                                left_on='userId',
                                right_index=True)
subset_df = users_data[users_data.users_counts >= 50]
rows_count, columns_count = subset_df.shape
print('Total Number of rows :', rows_count)
print('Total Number of columns :', columns_count)
subset_df.head()
# Out:
# Total Number of rows : 125871
# Total Number of columns : 4
#                 userId   productId  rating  users_counts
# 94      A3BY5KCNQZXV5U  0594451647     5.0            50
# 14863   A3BY5KCNQZXV5U  B00000JD4V     4.0            50
# 134213  A3BY5KCNQZXV5U  B000063574     5.0            50
# 338368  A3BY5KCNQZXV5U  B0000CDJP8     5.0            50
# 634048  A3BY5KCNQZXV5U  B0007Y794O     5.0            50

# %% [markdown]
# 9. Select Products which have more than 5 ratings

# %%
product_rating_counts = subset_df['productId'].value_counts().rename('product_rating_counts')
product_rating_data   = subset_df.merge(product_rating_counts.to_frame(),
                                left_on='productId',
                                right_index=True)
product_rating_data = product_rating_data[product_rating_data.product_rating_counts >= 5]
print(product_rating_data.head())
rows_count, columns_count = product_rating_data.shape
print('Total Number of rows :', rows_count)
print('Total Number of columns :', columns_count)
product_rating_data.head()
# Out:
#                 userId   productId  rating  users_counts  \
# 634048  A3BY5KCNQZXV5U  B0007Y794O     5.0            50
# 633970   AKT8TGIT6VVZ5  B0007Y794O     5.0           192
# 633944  A1ILWPH1GHUXE2  B0007Y794O     4.0            98
# 634073   A1ZM846Y7AUYD  B0007Y794O     4.0            77
# 633998  A2ED50E3KWKUKW  B0007Y794O     5.0            65
#
#         product_rating_counts
# 634048                     18
# 633970                     18
# 633944                     18
# 634073                     18
# 633998                     18
# Total Number of rows : 65290
# Total Number of columns : 5
#                 userId   productId  rating  users_counts  \
# 634048  A3BY5KCNQZXV5U  B0007Y794O     5.0            50
# 633970   AKT8TGIT6VVZ5  B0007Y794O     5.0           192
# 633944  A1ILWPH1GHUXE2  B0007Y794O     4.0            98
# 634073   A1ZM846Y7AUYD  B0007Y794O     4.0            77
# 633998  A2ED50E3KWKUKW  B0007Y794O     5.0            65
#
#         product_rating_counts
# 634048                     18
# 633970                     18
# 633944                     18
# 634073                     18
# 633998                     18

# %% [markdown]
# 10. Final Dataset after preprocessing

# %%
amazon_df = product_rating_data.copy()
panda_data = amazon_df.drop(['users_counts', 'product_rating_counts'], axis=1)
panda_data.info()
panda_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65290 entries, 634048 to 3827474
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   userId     65290 non-null  object
#  1   productId  65290 non-null  object
#  2   rating     65290 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 2.0+ MB
#                 userId   productId  rating
# 634048  A3BY5KCNQZXV5U  B0007Y794O     5.0
# 633970   AKT8TGIT6VVZ5  B0007Y794O     5.0
# 633944  A1ILWPH1GHUXE2  B0007Y794O     4.0
# 634073   A1ZM846Y7AUYD  B0007Y794O     4.0
# 633998  A2ED50E3KWKUKW  B0007Y794O     5.0

# %%
reader = Reader(rating_scale=(1, 5))
surprise_data = Dataset.load_from_df(panda_data[['userId', 'productId', 'rating']], reader)

# %% [markdown]
# 12. Split datasets to train and test sets

# %%
trainset, testset = train_test_split(surprise_data, test_size=.30, random_state=7)

# %% [markdown]
# 13. Popularity based filtering based on product ratings

# %%
#POPULARITY BASED FILTERING BASED ON PRODUCT RATINGS (FOR NEW CUSTOMERS)
products_df = pd.DataFrame(panda_data.groupby('productId')['rating'].mean()) #will take mean of ratings for each product
products_df['product_rating_counts'] = pd.DataFrame(panda_data.groupby('productId')['rating'].count()) #will take count of ratings for each product
print(products_df.head())
print(products_df.sort_values('rating', ascending=False).head())
print(products_df.sort_values('product_rating_counts', ascending=False).head())
# Out:
#               rating  product_rating_counts
# productId
# 1400501466  3.333333                      6
# 1400532655  3.833333                      6
# 1400599997  4.000000                      5
# 9983891212  4.875000                      8
# B00000DM9W  5.000000                      5
#             rating  product_rating_counts
# productId
# B00LGQ6HL8     5.0                      5
# B003DZJQQI     5.0                     14
# B005FDXF2C     5.0                      7
# B00I6CVPVC     5.0                      7
# B00B9KOCYA     5.0                      8
#               rating  product_rating_counts
# productId
# B0088CJT4U  4.218447                    206
# B003ES5ZUU  4.864130                    184
# B000N99BBC  4.772455                    167
# B007WTAJTO  4.701220                    164
# B00829TIEK  4.436242                    149

# %% [markdown]
# 14. Selecting best hyperparameters

# %%
start_time = time.time()

knn_param_grid = {'bsl_options': {'method': ['als', 'sgd'],
                              'reg': [1, 2]},
              'k': [15, 20, 25, 30,35,40,45,50,55,60,65,70],
              'sim_options': {'name': ['pearson_baseline']}
              }

knnmeans_gs = GridSearchCV(KNNWithMeans, knn_param_grid, measures=['rmse', 'mae'], cv=5, n_jobs=5)

knnmeans_gs.fit(surprise_data)

print(knnmeans_gs.best_score['rmse'])

print(knnmeans_gs.best_params['rmse'])

computational_time = time.time() - start_time
print('\nComputational Time : %0.3fs' %(computational_time))
# Out:
# 0.998835655284587
# {'bsl_options': {'method': 'sgd', 'reg': 2}, 'k': 30, 'sim_options': {'name': 'pearson_baseline', 'user_based': True}}
#
# Computational Time : 129.829s

# %% [markdown]
# 15. User based Collaborating Filtering

# %%
#USER BASED
start_time = time.time()

# Creating Model using best parameters
knnMeansUU_model = KNNWithMeans(k=60, sim_options={'name': 'pearson_baseline', 'user_based': True})

# Training the algorithm on the trainset
knnMeansUU_model.fit(trainset)

# Predicting for testset
prediction_knnMeansUU = knnMeansUU_model.test(testset)

# Evaluating RMSE, MAE of algorithm KNNWithMeans User-User on 5 split(s)
knnMeansUU_cv = cross_validate(knnMeansUU_model, surprise_data, measures=['RMSE', 'MAE'], cv=5, verbose=True)

# Storing Crossvalidation Results in dataframe
knnMeansUU_df = pd.DataFrame.from_dict(knnMeansUU_cv)
knnMeansUU_described = knnMeansUU_df.describe()
knnMeansUU_cv_results = pd.DataFrame([['KNNWithMeans User-User', knnMeansUU_described['test_rmse']['mean'], knnMeansUU_described['test_mae']['mean'], 
                           knnMeansUU_described['fit_time']['mean'], knnMeansUU_described['test_time']['mean']]],
                            columns = ['Model', 'RMSE', 'MAE', 'Fit Time', 'Test Time'])

#cv_results = cv_results.append(knnMeansUU_cv_results, ignore_index=True)

# get RMSE
print("\n\n==================== Model Evaluation ===============================")
accuracy.rmse(prediction_knnMeansUU, verbose=True)
print("=====================================================================")
accuracy.mae(prediction_knnMeansUU, verbose=True)

computational_time = time.time() - start_time
print('\n Computational Time : %0.3fs' %(computational_time))
#cv_results
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9978  0.9896  0.9973  1.0208  0.9879  0.9987  0.0117
# MAE (testset)     0.7063  0.7013  0.7015  0.7156  0.6981  0.7045  0.0061
# Fit time          0.24    0.24    0.26    0.24    0.26    0.25    0.01
# Test time         0.44    0.34    0.34    0.43    0.54    0.42    0.07
#
#
# ==================== Model Evaluation ===============================
# RMSE: 1.0046
# =====================================================================
# MAE:  0.7117
#
#  Computational Time : 4.721s

# %%
#uid='A23WPWLYT3P1CZ'
uid='AZBXKUH4AIW3X'
pid='B003RRY9RS'
#pid='0594451647'
# Get predictions

pred=knnMeansUU_model.predict(uid, pid, r_ui=4, verbose=True) #r_ui denotes actual rating aka expected rating, est is predicted rating
# Out:
# user: AZBXKUH4AIW3X item: B003RRY9RS r_ui = 4.00   est = 4.29   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}

# %% [markdown]
# 16. Item based Collaborative Filtering

# %%
#ITEM BASED
start_time = time.time()

# Creating Model using best parameters
knnMeansII_model = KNNWithMeans(k=60, sim_options={'name': 'pearson_baseline', 'user_based': False})

# Training the algorithm on the trainset
knnMeansII_model.fit(trainset)

# Predicting for testset
prediction_knnMeansII = knnMeansII_model.test(testset)

# Evaluating RMSE, MAE of algorithm KNNWithMeans Item-Item on 5 split(s)
knnMeansII_cv = cross_validate(knnMeansII_model, surprise_data, measures=['RMSE', 'MAE'], cv=5, verbose=True)

# Storing Crossvalidation Results in dataframe
knnMeansII_df = pd.DataFrame.from_dict(knnMeansII_cv)
knnMeansII_described = knnMeansII_df.describe()
knnMeansII_cv_results = pd.DataFrame([['KNNWithMeans Item-Item', knnMeansII_described['test_rmse']['mean'], knnMeansII_described['test_mae']['mean'], 
                           knnMeansII_described['fit_time']['mean'], knnMeansII_described['test_time']['mean']]],
                            columns = ['Model', 'RMSE', 'MAE', 'Fit Time', 'Test Time'])

#cv_results = cv_results.append(knnMeansII_cv_results, ignore_index=True)

# get RMSE
print("\n\n==================== Model Evaluation ===============================")
accuracy.rmse(prediction_knnMeansII, verbose=True)
print("=====================================================================")
accuracy.mae(prediction_knnMeansII, verbose=True)

computational_time = time.time() - start_time
print('\n Computational Time : %0.3fs' %(computational_time))
#cv_results
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0306  1.0238  1.0182  1.0101  1.0141  1.0194  0.0072
# MAE (testset)     0.7220  0.7188  0.7155  0.7128  0.7125  0.7163  0.0036
# Fit time          1.14    0.94    0.94    0.96    0.95    0.98    0.08
# Test time         0.81    0.82    0.93    0.80    0.81    0.83    0.05
#
#
# ==================== Model Evaluation ===============================
# RMSE: 1.0341
# =====================================================================
# MAE:  0.7254
#
#  Computational Time : 12.260s

# %% [markdown]
# 17. Recommending top five products in user based collaborative filtering

# %%
k=5
top_n = defaultdict(list)
def get_top_n(predictions, n=k):
    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

top_n = get_top_n(prediction_knnMeansUU, n=k)
top_n
# Out:
# defaultdict(list,
#             {'A1Z7U9K6X3FEOU': [('B000VDCT3C', 4.708571428571429),
#               ('B004Q81CKY', 4.428571428571429),
#               ('B002UT42UI', 4.428571428571429),
#               ('B00834SJNA', 4.428571428571429),
#               ('B002HU39BS', 4.428571428571429)],
#              'A18HE80910BTZI': [('B001HBH1B2', 4.648875133593654),
#               ('B00J238GV6', 4.325146198830409),
#               ('B003ZSHKIO', 4.263497453310697),
#               ('B0040JHVC2', 4.254857149460412),
#               ('B005HTIWF4', 4.187056100155953)],
#              'A1F1A0QQP2XVH5': [('B008X9Z44M', 4.787886359460263),
#               ('B002C7481G', 4.7534996408238035),
#               ('B00AJHDZSI', 4.750364248654246),
#               ('B00BOHNYU6', 4.693684672276373),
#               ('B00746LVOM', 4.64715854543668)],
#              'ARBKYIVNYWK3C': [('B0015YJOK2', 5),
#               ('B003WO7MZC', 5),
#               ('B00DVFLJDS', 5),
#               ('B001UI2FPE', 5),
#               ('B001OORMVQ', 5)],
#              'A2QDOJFFLFGF18': [('B00EL8NJ82', 5),
#               ('B00G4FCHH4', 5),
#               ('B00EUFP39E', 5),
#               ('B0002L5R78', 5),
#               ('B005DOUJL8', 5)],
#              'A1VLE2SH9J8WYS': [('B005FYNSPK', 5),
#               ('B0015DYMVO', 5),
#               ('B0011U65F2', 5),
#               ('B001EBE1LI', 5),
#               ('B0000510ZO', 5)],
#              'A23NSKTMSPPBTR': [('B00546JKJC', 4.580149855360376),
#               ('B00562O8U0', 4.493736329290117),
#               ('B005ZAO9PC', 4.466268811624286),
#               ('B004HIN7SI', 4.426126406686394),
#               ('B005GOINEK', 4.397913548099115)],
#              'A2NX6PABLIJLP1': [('B002JCSCYS', 5),
#               ('B00093IIRA', 4.928946162328435),
#               ('B003LZYXYU', 4.724137931034483),
#               ('B0009S5HQA', 4.724137931034483),
#               ('B00009EHJV', 4.724137931034483)],
#              'ABUE0ALHKWKHC': [('B00EAR8S76', 5),
#               ('B002WE6D44', 4.902777777777778),
#               ('B00426C57O', 4.902777777777778),
#               ('B0082E9K7U', 4.86),
#               ('B003ELYQGG', 4.86)],
#              'A37IRE9GZ0CZ7I': [('B00CI3BIWQ', 4.724789915966386),
#               ('B001ELJ9QK', 4.164158686730506),
#               ('B000067RC4', 4.117647058823529),
#               ('B005EOWBKE', 4.117647058823529),
#               ('B005DKZTMG', 4.117647058823529)],
#              'A2HDTOF8222KN3': [('B00011KM38', 5),
#               ('B00007EDM8', 5),
#               ('B0015V1H28', 5)],
#              'AX7317G153T8W': [('B002TLTGM6', 5),
#               ('B001FA1NZK', 5),
#               ('B00BQ5RY1G', 5),
#               ('B001E1Y5O6', 4.922171863047409),
#               ('B004CLYEA0', 4.767428112062962)],
#              'A1RDHBBZE1NPS3': [('B0097BEFYA', 5),
#               ('B00BOHNYU6', 4.541762287453814),
#               ('B00829THK0', 4.497849587442656),
#               ('B00G4JZ2T0', 4.190476190476191),
#               ('B00AEKEA48', 4.190476190476191)],
#              'A6XDZ1MJ0B1A2': [('B004XC6GJ0', 3.2666666666666666),
#               ('B004ZNA3UA', 3.2666666666666666),
#               ('B004MU8VCS', 3.2666666666666666),
#               ('B004XXMUCQ', 3.2666666666666666),
#               ('B00D7P6176', 3.2666666666666666)],
#              'AYMD77ITD15PT': [('B007IJ7UHC', 4.36223923952542),
#               ('B000YQ6DIS', 4.356231003039514),
#               ('B0002A9RFM', 4.228571428571429),
#               ('B005DSPL9E', 4.228571428571429),
#               ('B004CLYE8C', 4.228571428571429)],
#              'A781ITP3HE2N5': [('B004I5FL1G', 5),
#               ('B0012Y2LLE', 5),
#               ('B003UT2E8E', 4.833333333333333),
#               ('B0009STJIW', 4.833333333333333),
#               ('B0049P6OTI', 4.833333333333333)],
#              'A2O6HZ2B9YSRXR': [('B001TH7T2U', 4.681481481481482),
#               ('B004EBUXHQ', 4.481481481481482),
#               ('B002VKVZ1A', 4.481481481481482),
#               ('B005X64OA8', 4.481481481481482),
#               ('B002SIMPXM', 4.345444878402789)],
#              'A1M7HP5CHDXXOU': [('B00EVIBN26', 4.633333333333334),
#               ('B00426C57O', 4.633333333333334),
#               ('B00021XIJW', 4.633333333333334),
#               ('B00829THH8', 4.633333333333334),
#               ('B007471PZQ', 4.530103815018899)],
#              'A1SX9PHJWTDMF9': [('B0016OEV7C', 5),
#               ('B0029N3U8K', 5),
#               ('B00020S7XK', 5),
#               ('B000O8I474', 5),
#               ('B003ELYQGG', 5)],
#              'AWPODHOB4GFWL': [('B00BB6LTI4', 5),
#               ('B001TH7GT6', 5),
#               ('B004KPLNO8', 5),
#               ('B008KEPX1O', 5),
#               ('B00834SJNA', 5)],
#              'A3QQGPI3CTV9SX': [('B000HZBR64', 5),
#               ('B00004ZCJE', 5),
#               ('B00005LEN4', 5),
#               ('B0013AV4M4', 4.8076923076923075),
#               ('B000VRBLMS', 4.8076923076923075)],
#              'A31N0XY2UTB25C': [('B002SIMPXM', 5),
#               ('B003A7C9WM', 5),
#               ('B00005114Z', 5),
#               ('B000067SOH', 5),
#               ('B00752R4PK', 5)],
#              'A197T2N6RU7K56': [('B001OC6DCW', 5),
#               ('B00004ZCJE', 5),
#               ('B004NY9UV4', 5),
#               ('B001V9LQAW', 5),
#               ('B00825BZUY', 4.644011826901298)],
#              'A3094EPI56GKZ6': [('B00DQZSEWM', 5),
#               ('B00FNPD1OY', 5),
#               ('B00829TIA4', 5),
#               ('B000HPV3RW', 5),
#               ('B00EL8NJ82', 5)],
#              'A680RUE1FDO8B': [('B0018P7WZ2', 5),
#               ('B000WKW69Q', 5),
#               ('B0039NLS3I', 5),
#               ('B00I6CVPVC', 5),
#               ('B0002CPBUK', 5)],
#              'A3DGJMO6VPG6FJ': [('B006W8U2MU', 5),
#               ('B004QK7HI8', 4.698890866437471),
#               ('B00EO302SO', 4.64569683244051),
#               ('B00GBATPFO', 4.582538436315701),
#               ('B000KO0GY6', 4.561126166817224)],
#              'A2K5RRMPICZ606': [('B0019EHU8G', 5),
#               ('B003ES5ZUU', 5),
#               ('B00CRFK24K', 4.333333333333333),
#               ('B00009R86L', 4.333333333333333),
#               ('B000ZSUQ9M', 4.333333333333333)],
#              'A7EU2BWLLCJY2': [('B00IX2VGFA', 5),
#               ('B00EE1WUI6', 4.982267349059751),
#               ('B00D741DRK', 4.908900836320192),
#               ('B00ENZRS76', 4.878593896638147),
#               ('B006TL5KWC', 4.864433977101014)],
#              'A2UOHALGF2X77Q': [('B006VJT1K4', 5),
#               ('B0013DXVYK', 5),
#               ('B002VPE1Q6', 5),
#               ('B002IKLJU0', 5),
#               ('B00923G46U', 5)],
#              'A1EH2S92FHWZRP': [('B00INNP5VU', 5),
#               ('B00119T6NQ', 4.752374640759974),
#               ('B003ES5ZUU', 4.73993923663652),
#               ('B004SBBDD0', 4.680229267827009),
#               ('B002JCSV5I', 4.61509324009324)],
#              'A2QRXQPHDMFCQV': [('B00AQUO5RI', 4.024142416190342),
#               ('B004DMNT2W', 4.020249595867051),
#               ('B004GXAL42', 3.9726714673979666),
#               ('B009NB8WR0', 3.955882352941176),
#               ('B00DQZOIOU', 3.9299777891870007)],
#              'A1OES7R7FDAT2L': [('B000JE7GPY', 4.694594594594594),
#               ('B005FYNSPK', 4.6535499163143665),
#               ('B005HMKKH4', 4.642656628984174),
#               ('B002FRLEIS', 4.1),
#               ('B003N12TSY', 4.1)],
#              'ANRS196NKFVUU': [('B000233WJ6', 5),
#               ('B00001P4XH', 5),
#               ('B00475WJEY', 5),
#               ('B004S7Q8CA', 5),
#               ('B004TA0AUW', 5)],
#              'AQM0K7MBBT4AY': [('B00E3W15P0', 4.79072325300173),
#               ('B008D1JRIO', 4.651098018328946),
#               ('B00DBX371C', 4.489067800870575),
#               ('B004CLYE8C', 4.455579689025116),
#               ('B002K9IHGI', 4.392931063493555)],
#              'A3VC74TJ06WDDD': [('B00829THK0', 4.846408171855061),
#               ('B000XHS4SK', 4.411764705882353),
#               ('B00DR0PDNE', 4.411764705882353),
#               ('B0038W0K1G', 4.411764705882353),
#               ('B003UH0Z9Q', 4.411764705882353)],
#              'ANW6EGY12V5XS': [('B0045371FU', 5),
#               ('B00EXPNFQO', 4.954395757490249),
#               ('B00G53GJ88', 4.917625231910947),
#               ('B0001FTVE0', 4.867704976727533),
#               ('B00GMGDFPI', 4.489239761827418)],
#              'ABIVKBMSIPEDY': [('B000UEZ36W', 5),
#               ('B00GBATPFO', 4.719868357849695),
#               ('B001DJ64C0', 4.692521506244415),
#               ('B00FR6VL50', 4.6831410287823765),
#               ('B008MJ01QE', 4.643296142925334)],
#              'A2IMLOJ2Z2QEU2': [('B0002WPSBC', 5),
#               ('B0035FZ12O', 4.862166321505882),
#               ('B00407VXKU', 4.822251195132551),
#               ('B00654PTT2', 4.778397367304379),
#               ('B005KAK2FI', 4.764853866014636)],
#              'AFICF7DKHTQ87': [('B00EYTM3DK', 4.5476190476190474),
#               ('B00HYAL84G', 4.529017857142858),
#               ('B0076MBOC8', 4.367989041859136),
#               ('B00HFAEBWG', 4.047520871018662),
#               ('B00DQZOD8Q', 4.039978351239144)],
#              'A25KKXUQQ0OLWB': [('B0088CJT4U', 5),
#               ('B00DQZO0R0', 5),
#               ('B004GCJEZU', 4.832915798828654),
#               ('B008OIYDM6', 4.823529411764706),
#               ('B005KDYBIO', 4.823529411764706)],
#              'A2PJH18W4XHTZW': [('B001XURP7W', 5),
#               ('B0009K9FZW', 5),
#               ('B000CLNHXY', 4.785829307568438),
#               ('B002V88HFE', 4.644611777745427),
#               ('B001423GZO', 4.481481481481482)],
#              'A2VJ5ALN1BIV3B': [('B001GTT0VO', 5),
#               ('B007WTAJTO', 4.871570111440024),
#               ('B000M2TAN4', 4.5),
#               ('B0051G5SBY', 4.5),
#               ('B00466X9SY', 4.5)],
#              'AR1T36GLLAFFX': [('B003ES5ZQE', 4.222222222222222),
#               ('B001MT8J4W', 4.222222222222222),
#               ('B004Q3R9AQ', 4.222222222222222),
#               ('B000BQ7GW8', 4.222222222222222),
#               ('B002VPE1Z2', 4.222222222222222)],
#              'A35HNL2VEDK9Z1': [('B00007E89K', 4.537301587301588),
#               ('B00BOZ1Y46', 4.515807962529275),
#               ('B000BTCJNG', 4.36344537815126),
#               ('B0009GZAGO', 4.362857142857143),
#               ('B00005LEN4', 4.188514675631621)],
#              'A4GGT6O0GQNV2': [('B00FNPD1OY', 4.444444444444445),
#               ('B00BGA9WK2', 4.444444444444445),
#               ('B005CPGHAA', 4.444444444444445),
#               ('B007KXI2R8', 4.444444444444445),
#               ('B00D5Q75RC', 4.444444444444445)],
#              'A2BLFCOPSMBOZ9': [('B005D5M136', 5),
#               ('B00GJYJFKM', 4.990149140685427),
#               ('B001TH7GUA', 4.844407088124869),
#               ('B003HFCDLY', 4.816224852263032),
#               ('B00CUBMF8W', 4.698217037200088)],
#              'A100WO06OQR8BQ': [('B003MVZ60I', 5),
#               ('B000VX6XL6', 4.8644506454418925),
#               ('B0009YJXMS', 4.4037037037037035),
#               ('B00434OWDA', 4.278285847810637),
#               ('B00CGYCOR0', 4.247181964573269)],
#              'A3G7BEJJCPD6DS': [('B002GP7ZT6', 4.756329961558605),
#               ('B004J4VYEY', 4.658244680851064),
#               ('B00634PLTW', 4.3793347440235895),
#               ('B009YT6PPC', 4.160830916261582),
#               ('B0040702HU', 4.0625)],
#              'A1CYTBE7LLUQ8F': [('B004R7A9NU', 5),
#               ('B001EZRJZE', 5),
#               ('B0002IWC9C', 4.85),
#               ('B00093IIRA', 4.85),
#               ('B002QEBMAK', 4.85)],
#              'AHROSV6WJOEGY': [('B0002GDIII', 3.4285714285714284),
#               ('B001D7REIK', 3.4285714285714284),
#               ('B0007QKMQY', 3.4285714285714284),
#               ('B003LPTAYI', 3.4285714285714284),
#               ('B000V1MLBE', 3.4285714285714284)],
#              'A3FBM0RMCMAABV': [('B00A6UYCT4', 5),
#               ('B00DQZQG3G', 5),
#               ('B008ULPD0S', 4.888515791358118),
#               ('B00834SJSK', 4.808007531773779),
#               ('B006ZBWV0K', 4.687840597277765)],
#              'A2X61KKXXR6WNP': [('B005KQ2O26', 5),
#               ('B004CLYEDC', 4.9476172027730545),
#               ('B004QMA3U0', 4.727891156462585),
#               ('B0035JJJQE', 4.523809523809524),
#               ('B001D1O3T4', 4.523809523809524)],
#              'AEJAGHLC675A7': [('B001CK9760', 5),
#               ('B005CG2ATQ', 5),
#               ('B008ZGKWQI', 5),
#               ('B00267S7TQ', 5),
#               ('B002Y6CJJ8', 5)],
#              'A2OBDNQ5ZYU1L8': [('B00EUFP39E', 5),
#               ('B0038KV2MO', 4.823180275738929),
#               ('B00D65AJ0C', 4.807944073081346),
#               ('B00BXF5GKK', 4.6256567862025095),
#               ('B00175VDY4', 4.622227268989211)],
#              'A3R19YKNL641X3': [('B002GP7ZT6', 5),
#               ('B00DVS98XS', 4.896820349761526),
#               ('B002Y5XQYG', 4.877551117030979),
#               ('B00834SJSK', 4.76824364055879),
#               ('B00DR6DQZA', 4.6288432932027375)],
#              'A28BX3MM90A6FI': [('B00CRFK24K', 5),
#               ('B004TJ6JH6', 5),
#               ('B002KETE24', 5),
#               ('B003F69JBW', 5),
#               ('B001XURP7W', 4.852591726103393)],
#              'A3NKRH3TJ4DPVI': [('B0018MEBNG', 5),
#               ('B003WGJYCY', 5),
#               ('B000ONZTMW', 5),
#               ('B003ES5ZUU', 5),
#               ('B00C28L6EW', 4.7357048453525525)],
#              'A30X750M8V1XXW': [('B001AGM2VI', 4.847331739029623),
#               ('B001XURPQI', 4.53551912568306),
#               ('B0016BVKAQ', 4.504268665999055),
#               ('B005KAK2FI', 4.483748533405164),
#               ('B0043M668G', 4.475207752561298)],
#              'AG5WSXI52FPKH': [('B004W2JKWG', 4.730485066819058),
#               ('B000Q82PIQ', 4.222222222222222),
#               ('B00008VF63', 4.222222222222222),
#               ('B000HDJY7K', 4.222222222222222),
#               ('B000V0GXR8', 4.222222222222222)],
#              'A2PREU4LOFQRB1': [('B000N99BBC', 5),
#               ('B006DEBYWU', 5),
#               ('B00GK22DF2', 4.946581196581197),
#               ('B00EXK14S0', 4.820087760555522),
#               ('B005HGBEZ2', 4.388888888888889)],
#              'A3LGT6UZL99IW1': [('B0076MBOC8', 5),
#               ('B004OR14H8', 5),
#               ('B00E60PZFK', 4.993437186605737),
#               ('B000L47AHG', 4.955494552143358),
#               ('B00429N16A', 4.936341299977664)],
#              'A2FRKEXDXDN1KI': [('B00FAYL1YU', 5),
#               ('B004DYQRME', 4.914545454545454),
#               ('B007ABIY4Q', 4.844646775882492),
#               ('B00BUJBHGG', 4.824963503649635),
#               ('B002SZEOLG', 4.797867763866047)],
#              'A36K2N527TXXJN': [('B001FA1NZK', 5),
#               ('B002K9IHGI', 5),
#               ('B001FN14RE', 5),
#               ('B00BOHNYTW', 5),
#               ('B000HPV3RW', 5)],
#              'A1PSVZBM894R5H': [('B00168Q248', 3.5789473684210527),
#               ('B003CJTQJC', 3.5789473684210527),
#               ('B00006B7DB', 3.5789473684210527),
#               ('B00007056H', 3.5789473684210527),
#               ('B002LITT6U', 3.5789473684210527)],
#              'A1DSRM2P0WGQNS': [('B005O88CUS', 4.427350427350428),
#               ('B0010WG2H2', 4.247222880113097),
#               ('B006TF3746', 4.169984368054763),
#               ('B001E25JOA', 3.888888888888889),
#               ('B002IC0YLS', 3.888888888888889)],
#              'A18EA7MNLXP9H5': [('B002Y6CJJ8', 4.95),
#               ('B000067RT6', 4.221503665817268),
#               ('B000JLG5ZY', 4.0),
#               ('B0012YFXSW', 4.0),
#               ('B003VAGXZC', 4.0)],
#              'A2X3L31KCXBHCL': [('B00BUER7EC', 4.82691201840138),
#               ('B000J47W12', 4.732640332640333),
#               ('B00BWL33H8', 4.625762983818249),
#               ('B000JMJWV2', 4.620413634271774),
#               ('B002BW6DBU', 4.486486486486487)],
#              'A1H98YV5K5BUX0': [('B0019EHU8G', 4.6521739130434785),
#               ('B000EM8GDW', 4.6521739130434785),
#               ('B000UMX7FI', 4.6521739130434785),
#               ('B001EQ4BVI', 4.6521739130434785),
#               ('B00093IIRA', 4.6521739130434785)],
#              'A2NQMVTQ4PVLL': [('B0088PUEPK', 5),
#               ('B000I23TTE', 5),
#               ('B008JJLW4M', 5),
#               ('B0021Y73W6', 5),
#               ('B00006B7DA', 5)],
#              'ABQWMANK4AR63': [('B00BQHD4B8', 4.779111361226917),
#               ('B004LNXO28', 4.695583341861609),
#               ('B00BPHH8MA', 4.5622357602512595),
#               ('B00AR95ESC', 4.546569807994095),
#               ('B00A0ABQLM', 4.479414298018949)],
#              'AP53MVRC8ZEW2': [('B004RFBIUU', 4.833333333333333),
#               ('B007SZ0EHE', 4.833333333333333),
#               ('B00066FH1U', 4.833333333333333),
#               ('B004CRSM4I', 4.833333333333333),
#               ('B000UHQVOW', 4.833333333333333)],
#              'A1IU7S4HCK1XK0': [('B0001A06GW', 5),
#               ('B000N99BBC', 5),
#               ('B00DQZQPNM', 5),
#               ('B00DR0B7Y8', 5),
#               ('B00JC5Y6WM', 4.966561472402729)],
#              'A3077MQTAKOVFZ': [('B003ES5ZUU', 5),
#               ('B005JACJ50', 4.795125666412795),
#               ('B0063705PE', 4.230769230769231),
#               ('B004X28I0A', 4.230769230769231),
#               ('B004MMEI8W', 4.230769230769231)],
#              'ASHJAZC9OA9NS': [('B004E0ZLZQ', 5),
#               ('B002AH2AH2', 5),
#               ('B0083WYFWG', 5),
#               ('B00092GM0Q', 5),
#               ('B000HDFXU2', 5)],
#              'A1GQRGB8FGSLIZ': [('B003ES5ZUU', 4.401097691327832),
#               ('B009EOJKEU', 4.302859042553191),
#               ('B00BQ4F9ZA', 4.302859042553191),
#               ('B00EVIBN8U', 4.221449043956767),
#               ('B000N99BBC', 4.193706219013292)],
#              'A11YIHB6IW352W': [('B008HO9DK4', 5),
#               ('B001K9BFB8', 4.6521739130434785),
#               ('B001CY0P7G', 4.6521739130434785),
#               ('B000OGX5AM', 4.6521739130434785),
#               ('B002QEBMAK', 4.6521739130434785)],
#              'A84FLVDK2R5JF': [('B004LB4MZS', 5),
#               ('B0036RFGKS', 5),
#               ('B005J2F7NE', 5),
#               ('B001P05NBA', 5),
#               ('B002TLTE6O', 4.977104736486803)],
#              'A1KD8NJPZ01R37': [('B005FVDTAW', 3.909090909090909),
#               ('B0070UFMOW', 3.909090909090909),
#               ('B003ZBZ64Q', 3.909090909090909),
#               ('B002OB49SC', 3.909090909090909),
#               ('B008CS5T76', 3.909090909090909)],
#              'A19FRW264WZTGP': [('B000Q8UAWY', 5),
#               ('B004CLYEFK', 5),
#               ('B00JC5Y6WM', 5),
#               ('B003M0NURK', 4.978832366309611),
#               ('B00829THK0', 4.926919871625466)],
#              'A1JUBRIZMO0RJV': [('B00829THEG', 5),
#               ('B001FA1NZU', 4.976097348978705),
#               ('B00CD8ADKO', 4.87948717948718),
#               ('B00AJHDZSI', 4.5366300366300365),
#               ('B000A3WS16', 4.296238758943614)],
#              'A38KK0SZYEH5UD': [('B002FL507A', 5),
#               ('B0042X9L6A', 5),
#               ('B001AZ01EO', 5),
#               ('B00C87D0XM', 5),
#               ('B0019EHU8G', 5)],
#              'A3SRDVCD2ATIIS': [('B002WE4HE2', 5),
#               ('B004TA0AUW', 4.714285714285714),
#               ('B000TKHBDK', 4.714285714285714),
#               ('B0025ZH43O', 4.714285714285714),
#               ('B002DUEBIC', 4.714285714285714)],
#              'A2FXBWR4T4OFQ': [('B0009JB7GI', 5),
#               ('B000LRMS66', 5),
#               ('B002O3MVYO', 4.889011572755444),
#               ('B004TJ6JH6', 4.736547788238687),
#               ('B009C98NPY', 4.695652173913044)],
#              'A3QNX5KWHDV0GD': [('B00889ST2G', 3.423076923076923),
#               ('B003ELOSIW', 3.423076923076923),
#               ('B009WHV3BM', 3.423076923076923),
#               ('B00065AO0K', 3.423076923076923),
#               ('B00AXVXXNC', 3.423076923076923)],
#              'A2SH7OWE8QJYNC': [('B005KJJKVG', 4.363636363636363),
#               ('B007PJ4PKK', 4.363636363636363),
#               ('B006DY3CRK', 4.363636363636363),
#               ('B00008W2LC', 4.363636363636363),
#               ('B00FC2R7ZC', 4.363636363636363)],
#              'AHF4I1FSIHABC': [('B0002Y5WZM', 5),
#               ('B00004WCID', 5),
#               ('B00004ZC8Y', 5),
#               ('B002WE0QN8', 5),
#               ('B006TT91TW', 4.888686727760081)],
#              'AETQIN7OH0RL9': [('B003ES5ZUU', 4.164897456037075),
#               ('B001CCAISE', 4.107716980192672),
#               ('B003TYDBYQ', 4.003496503496503),
#               ('B009B0MZ8U', 3.87987012987013),
#               ('B008JJLW4M', 3.772727272727273)],
#              'ATS2855497V0I': [('B004HKJTT2', 4.635561968895302),
#               ('B000N99BBC', 4.387165646321168),
#               ('B0028Y4H1O', 4.36553910438943),
#               ('B00EJ8CURK', 4.296238758943614),
#               ('B004CLYEDC', 4.275743600075695)],
#              'A1E1LEVQ9VQNK': [('B00DDH4TYA', 5),
#               ('B009NHWVIA', 5),
#               ('B00DVEJA7G', 5),
#               ('B00E3FHXYO', 5),
#               ('B00DQZP7X6', 5)],
#              'A2DG63DN704LOI': [('B005IA843W', 5),
#               ('B003NREDG4', 5),
#               ('B00127VAW2', 5),
#               ('B00AQUO5RI', 5),
#               ('B00F0DD0I6', 5)],
#              'A30UP2KKD5IQEP': [('B008YDTRZ4', 5),
#               ('B00CGYCOR0', 5),
#               ('B003ES5ZUU', 5),
#               ('B002K9IHGI', 4.951798626874207),
#               ('B005PUZOYM', 4.896911989777087)],
#              'A2WPL6Y08K6ZQH': [('B003ELOSIW', 5),
#               ('B000U5TUWE', 5),
#               ('B00EB7UIO6', 5),
#               ('B003YKG2WI', 4.814671814671814),
#               ('B00E98O7GC', 4.78490990990991)],
#              'A17UNMURMLX0ZE': [('B005WKKIGO', 5),
#               ('B005HSDLCO', 4.949971247843588),
#               ('B00834SJSK', 4.647660435464573),
#               ('B009NHWVIA', 4.621391648881111),
#               ('B0079UAT0A', 4.515488161552066)],
#              'A1F7YU6O5RU432': [('B00BB72WX4', 5),
#               ('B002K9IHGI', 5),
#               ('B00BGA9WK2', 5),
#               ('B007MDQIH2', 5),
#               ('B002Y6CJJ8', 5)],
#              'A2EHYCA29NSQLU': [('B001R5FRMI', 4.296238758943614),
#               ('B0056VOM2U', 2.5),
#               ('B00E3FHXYO', 2.5),
#               ('B00FFJ0HUE', 2.5),
#               ('B0012MI7N2', 2.5)],
#              'AVJORH3ACR2A5': [('B000MX48VM', 5),
#               ('B008MDSWI4', 4.764705882352941),
#               ('B005TUQV0E', 4.764705882352941),
#               ('B00CGUMR2Q', 4.764705882352941),
#               ('B002B8WVVU', 4.764705882352941)],
#              'AA95DWUI3ODU': [('B007WTAJTO', 4.455645161290323),
#               ('B00746LVOM', 3.875),
#               ('B00F3SOHNU', 3.875),
#               ('B00HWMPRKM', 3.875),
#               ('B00KHA2DQM', 3.875)],
#              'AEWYUPCNDV7HY': [('B007SHJIO2', 5),
#               ('B0001DBEM4', 4.9707191780821915),
#               ('B0046HAO40', 4.938349784804688),
#               ('B00DW9U3B2', 4.67193396226415),
#               ('B0051GN9JC', 4.656170886075949)],
#              'A2XX2A4OJCDNLZ': [('B00GMTN96U', 5),
#               ('B001B8CSQ4', 5),
#               ('B0019EHU8G', 5),
#               ('B003XN24GY', 5),
#               ('B0082E9K7U', 4.960718655379707)],
#              'A30JPZ9TZ7I61U': [('B0097FZRYI', 5),
#               ('B007X3VC7W', 5),
#               ('B009HQCARY', 4.826036866359447),
#               ('B0058FAYPI', 4.690322580645161),
#               ('B00A3YDPWS', 4.639290104517241)],
#              'A3EFSLEMHNPP6A': [('B00176TEGM', 5),
#               ('B0035JJJQE', 5),
#               ('B003VAM32E', 5),
#               ('B003VANO7C', 4.934343434343435),
#               ('B004T9RR4A', 4.89119922630561)],
#              'A2SH6A32BE6NEV': [('B000TS7I6C', 5),
#               ('B00EOI2SR2', 4.944620253164557),
#               ('B0081FLFQE', 4.923089426493199),
#               ('B0088CJT4U', 4.599390957401895),
#               ('B001DJ64D4', 4.375)],
#              'AN9CP6J4JF91X': [('B001TDL34Y', 5),
#               ('B00483WRZ6', 5),
#               ('B005HMKKH4', 4.968559520154726),
#               ('B004M8SSZK', 4.875),
#               ('B000KO0GY6', 4.875)],
#              'A2SR7S6ZJJDGNB': [('B00DVFLJDS', 5),
#               ('B00D029NNA', 5),
#               ('B006JG2IPY', 4.916666666666667),
#               ('B0096YOQQA', 4.916666666666667),
#               ('B002J9HBIO', 4.916666666666667)],
#              'A1J87SYB3JPQWH': [('B003TLSXMO', 4.5),
#               ('B003ZX871I', 4.5),
#               ('B000JLK5PK', 4.5),
#               ('B0036Q7MV0', 4.5),
#               ('B001G5ZTLS', 4.5)],
#              'A1H4IVXNXWWBLV': [('B0019EQ1RW', 4.2272727272727275),
#               ('B003ZX8B0U', 4.2272727272727275),
#               ('B001FA1O18', 4.2272727272727275),
#               ('B000WL6YY8', 4.2272727272727275),
#               ('B00067LYFW', 4.2272727272727275)],
#              'AT28RL25Q2OLK': [('B003ES5ZUU', 4.937194202298302),
#               ('B008DWCRQW', 4.930493267199245),
#               ('B004XVN17G', 4.9059027777777775),
#               ('B0000BZL1P', 4.844791666666667),
#               ('B006TF37H8', 4.844791666666667)],
#              'ASCBJEPXTOU0V': [('B008I646WG', 5),
#               ('B009W8YQ6K', 5),
#               ('B008NMCPTQ', 5),
#               ('B0058UUR6E', 4.854602443518514),
#               ('B008RJZQSW', 4.702732342497692)],
#              'A3V5F050GVZ56Q': [('B003ES5ZUU', 5),
#               ('B0049YQVHE', 5),
#               ('B00D50UNRM', 5),
#               ('B00IX2VGFA', 5),
#               ('B000067RT6', 5)],
#              'A4IL0CLL27Q33': [('B008O2HW8O', 4.9154849688031765),
#               ('B003XU6H8I', 4.658912352428038),
#               ('B009YT6PPC', 4.559549982042042),
#               ('B00829THK0', 4.492889626094575),
#               ('B003CJTQJW', 4.232558139534884)],
#              'A3NG7X4APIV649': [('B005IA843W', 5),
#               ('B008V9RW58', 5),
#               ('B000I1X6PM', 4.966233766233766),
#               ('B001FA1O0O', 4.803420735862112),
#               ('B0094R4POC', 4.75)],
#              'A1MRRMHGV3PN5W': [('B005A0B7CA', 4.918771478317411),
#               ('B000N99BBC', 4.816956287464191),
#               ('B008DWCRQW', 4.425715622647015),
#               ('B00FG38L16', 4.205882352941177),
#               ('B003ZYF3LO', 4.205882352941177)],
#              'A1U11IP6K6NHAK': [('B00BA8596G', 5),
#               ('B00CMJZAOI', 5),
#               ('B006OM75I8', 5),
#               ('B00AIHYHJA', 4.828877005347594),
#               ('B00IMZKDOS', 4.685674101986392)],
#              'AKBVYIIHWI04B': [('B0049YQVHE', 5),
#               ('B00FG7MMDK', 5),
#               ('B00609B3J2', 5),
#               ('B00316263Y', 5),
#               ('B000VZS2EU', 5)],
#              'A1ZCSSCAGBCD49': [('B00AAHT8JC', 4.488599912420116),
#               ('B00DTPYQBM', 4.285171113029889),
#               ('B00829THK0', 4.2824445370853),
#               ('B001L2MJO6', 4.280995574786527),
#               ('B009C98NPY', 4.238459441095467)],
#              'A12R3YGEHW7D8G': [('B002HWRJBM', 5),
#               ('B0099SMFVQ', 5),
#               ('B007WTAJTO', 4.681203007518797),
#               ('B00137NMMW', 4.428571428571429),
#               ('B0062IPIPQ', 4.428571428571429)],
#              'A7EJERNB7IK3Z': [('B000V1MLBE', 4.52808742793555),
#               ('B000MVJ1M0', 4.294117647058823),
#               ('B008CS5T76', 4.294117647058823),
#               ('B002Y6CJJ8', 4.294117647058823),
#               ('B000L4D42Q', 4.294117647058823)],
#              'A362FM6FYA1SYS': [('B007SZ0E1K', 5),
#               ('B0000A1G05', 4.72),
#               ('B0042X9L6A', 4.72),
#               ('B005ES0YYA', 4.72),
#               ('B007P8HV2K', 4.72)],
#              'A3TA1UJWRJF9NC': [('B0038W0K2K', 5),
#               ('B000A6PPOK', 5),
#               ('B0056BPUQC', 4.894736842105263),
#               ('B0007N55NW', 4.894736842105263),
#               ('B00004T8R2', 4.894736842105263)],
#              'A38RMU1Y5TDP9': [('B003U7SR0U', 5),
#               ('B005GMRVZO', 5),
#               ('B001TANZ0W', 5),
#               ('B0099XGZXA', 5),
#               ('B001RCTA8I', 4.982457315031805)],
#              'A1VTCSCH8FFC76': [('B003N7NMO8', 5),
#               ('B0035J7XG2', 5),
#               ('B001D7REIK', 5),
#               ('B0041RSHWG', 4.632352941176471),
#               ('B002WE6D44', 4.526828622421618)],
#              'A3FOSLM5G1BO63': [('B005YQXMAK', 4.528682547399125),
#               ('B0094R4PBU', 4.42577030812325),
#               ('B00825BZUY', 4.263594655491263),
#               ('B008E18PDG', 4.216775599128541),
#               ('B009O7XO1C', 3.989252396786264)],
#              'ASFP250F22MDZ': [('B0079UAT0A', 3.972400673370835),
#               ('B003YKG2XM', 3.52),
#               ('B005L38VPC', 3.52),
#               ('B00007E7QS', 3.52),
#               ('B000AAZQJU', 3.52)],
#              'A3SMD3T0QTN109': [('B00829THEG', 5),
#               ('B00DLKE7OQ', 5),
#               ('B0042FZ50O', 5),
#               ('B0043M668G', 4.994205541595207),
#               ('B00EB1ZZSG', 4.803030303030304)],
#              'AJL3U764D7NI3': [('B000CKVOOY', 5),
#               ('B007PLL4CK', 4.714285714285714),
#               ('B004K1EZDS', 4.714285714285714),
#               ('B00CDY0DSA', 4.714285714285714),
#               ('B002G1YNQS', 4.714285714285714)],
#              'A145LBW8ZHF0TW': [('B00113PUJQ', 3.6923076923076925),
#               ('B000IF4788', 3.6923076923076925),
#               ('B00007M1TZ', 3.6923076923076925),
#               ('B001TOD7ME', 3.6923076923076925),
#               ('B0049P6OTI', 3.6923076923076925)],
#              'A9LNWA25IM2DX': [('B002TOJXMQ', 5),
#               ('B005DSPLCQ', 5),
#               ('B00834SJNA', 4.724046330561867),
#               ('B0031RG29M', 4.600378787878787),
#               ('B000NLLXVQ', 4.470765512313356)],
#              'ANTGGAQYPSWHF': [('B00HFAEBWG', 4.179160356242128),
#               ('B00966OWKI', 4.05),
#               ('B004T9RR0E', 4.05),
#               ('B000OLDG60', 4.05),
#               ('B00654PTT2', 4.05)],
#              'AOWF9T81XMX2S': [('B002MAPSQM', 5),
#               ('B001342KM8', 5),
#               ('B008EQZ25K', 4.949906542056074),
#               ('B002RL875A', 4.52),
#               ('B0016XIQ1U', 4.52)],
#              'A3GX0FAMEXV6FB': [('B002ZV51DI', 4.2272727272727275),
#               ('B005B3VO24', 4.2272727272727275),
#               ('B005EOWBHC', 4.2272727272727275),
#               ('B004OVECU0', 4.2272727272727275),
#               ('B003VOW5WI', 4.2272727272727275)],
#              'A2IFGGXG3YV3Y6': [('B00DR0C96S', 5),
#               ('B00DMS0GTC', 5),
#               ('B003ES5ZUU', 5),
#               ('B0038W0K1G', 5),
#               ('B00CRFK24K', 4.94149630186521)],
#              'A1P0JSFW184ZXJ': [('B002TLTE6O', 5),
#               ('B00BWHILCY', 5),
#               ('B0025ZH43O', 5),
#               ('B0014KOB6Y', 5),
#               ('B003LRVNUU', 5)],
#              'A17BUUBOU0598B': [('B002LLJJAS', 4.164635741092981),
#               ('B002OGMNT4', 4.14375),
#               ('B0013AV4M4', 4.053427419354839),
#               ('B009NHWVIA', 4.0336760251262325),
#               ('B000FVGM38', 4.0287551345392245)],
#              'A36IHC0K68NS2': [('B00DR8LA60', 4.311459307259019),
#               ('B004ROOCO0', 4.092424242424242),
#               ('B00829TIEK', 4.021773400853386),
#               ('B00CRY250U', 3.7138649940128174),
#               ('B003LSTD38', 3.555635120021774)],
#              'A7UPJYPAH73NC': [('B005JW6WQU', 5),
#               ('B005NHR6MU', 5),
#               ('B004WOBCWU', 4.879500183592162),
#               ('B0016BVKAQ', 4.782962177447861),
#               ('B007JCNOHS', 4.536585365853658)],
#              'A3ER6ARJ23CIN8': [('B001E1Y5O6', 5),
#               ('B001C20816', 5),
#               ('B003ES5ZSW', 5),
#               ('B003UE52ME', 5),
#               ('B0051G5SBY', 4.774193548387097)],
#              'A226VGZWOEBPGL': [('B004LB4MZS', 5),
#               ('B0054JE70G', 5),
#               ('B007DC89OW', 5),
#               ('B0036RFGKS', 5),
#               ('B0041OSQ9I', 4.995904070186588)],
#              'A11EYMH9UV9XG7': [('B00CGWNKVQ', 5),
#               ('B000N99BBC', 4.840871737999907),
#               ('B008C1JC4O', 4.587324531658022),
#               ('B004W2T33W', 4.260869565217392),
#               ('B003YKG2W8', 4.260869565217392)],
#              'AV8MDYLHHTUOY': [('B00CRY250U', 4.9231636786029815),
#               ('B004SBBDD0', 4.842682926829268),
#               ('B004CLYEDC', 4.699485818369375),
#               ('B00DR6DQZA', 4.530755415581497),
#               ('B00EAXRVLY', 4.494860513167032)],
#              'A22S7D0LP8GRDH': [('B0036R9YA6', 5),
#               ('B003ES5ZUU', 5),
#               ('B003YKG2WI', 5),
#               ('B001U02JZ8', 4.991129866757756),
#               ('B001NTBVPA', 4.910297746795708)],
#              'A25TNBMJ4ZO7RD': [('B0009Q4PH4', 4.095238095238095),
#               ('B004K1EZDS', 4.095238095238095),
#               ('B00CL8F98W', 4.095238095238095),
#               ('B0007Y791C', 4.095238095238095),
#               ('B00HLDFUM2', 4.095238095238095)],
#              'A2HMF8ZR67BNZS': [('B00006I5J7', 5),
#               ('B003HFCDLY', 5),
#               ('B001F8SCRE', 5),
#               ('B001TH7GUA', 5),
#               ('B00483WRZ6', 5)],
#              'A35Q0RBM3YNQNF': [('B00FF8ZRR8', 5),
#               ('B0002LEMWE', 5),
#               ('B009A68TMQ', 4.948011094743392),
#               ('B00L3YHF6O', 4.924628026768833),
#               ('B00FRMAOIO', 4.914862914862915)],
#              'A314KKDIJWCNMV': [('B008RM235I', 5),
#               ('B002WE6D44', 4.956018518518518),
#               ('B00108UNEY', 4.4375),
#               ('B002Y6CJJ8', 4.4375),
#               ('B004GF8TIK', 4.4375)],
#              'A3N4I2KRSMACW8': [('B0010Y414Q', 4.3190045248868785),
#               ('B005J2E2US', 3.230769230769231),
#               ('B003XIM3QK', 3.230769230769231),
#               ('B001X017G2', 3.230769230769231),
#               ('B005DIBHA6', 3.230769230769231)],
#              'A2V1J3JT5OOZFO': [('B007R5YDYA', 4.787541713014461),
#               ('B0049V0ZX8', 4.206896551724138),
#               ('B001FWBUUG', 4.206896551724138),
#               ('B000UKMZ94', 4.206896551724138),
#               ('B0011Z2402', 4.206896551724138)],
#              'AKSFZ4G1AXYFC': [('B002SZEOLG', 4.778584392014519),
#               ('B000Q8UAWY', 4.722251172485669),
#               ('B0015TJNEY', 4.157894736842105),
#               ('B000FOYMKU', 4.157894736842105),
#               ('B000FFISV8', 4.157894736842105)],
#              'A3HR0ZZOFKQ97N': [('B00HFRWWAM', 5),
#               ('B00834SJNA', 5),
#               ('B0036Q7MV0', 5),
#               ('B0019EHU8G', 4.965662586606063),
#               ('B002MZUNXU', 4.859628367714416)],
#              'AB094YABX21WQ': [('B007F9XHBI', 5),
#               ('B000RQSGYO', 4.922727272727273),
#               ('B002WE6D44', 4.828282828282828),
#               ('B00494XZ1Y', 4.7727272727272725),
#               ('B004S76NH0', 4.7727272727272725)],
#              'A3S3R88HA0HZG3': [('B0053R0WWG', 5),
#               ('B00175VDY4', 5),
#               ('B001L2MJO6', 5),
#               ('B001SEQSDK', 5),
#               ('B000AP05BO', 5)],
#              'A1VLVWTLV3LVHR': [('B002J9HBIO', 4.083333333333333),
#               ('B00065XSP8', 4.083333333333333),
#               ('B001C4ETU0', 3.9761904761904763)],
#              'A1A535TCGNMVPI': [('B001DJ64D4', 4.982368693306147),
#               ('B005INAVHQ', 4.484848484848484),
#               ('B007L5NKZO', 4.484848484848484),
#               ('B00FZ9SMVU', 4.484848484848484),
#               ('B00G2HV3OM', 4.484848484848484)],
#              'A23GFTVIETX7DS': [('B009M3UT16', 5),
#               ('B00F0DD0I6', 5),
#               ('B00DK9N154', 4.994778473547644),
#               ('B001FA1NZK', 4.961698863202071),
#               ('B002WE4HE2', 4.945591335455661)],
#              'A15QYHQH80W30L': [('B00009MDBQ', 5),
#               ('B00015GYU4', 5),
#               ('B000VDCT3C', 5),
#               ('B004W2JKWG', 4.784126984126984),
#               ('B000VJX7DW', 4.736403951956312)],
#              'A2NN1KIYEM2SKS': [('B005FYNSPK', 5),
#               ('B00GLJGJTA', 4.37008547008547),
#               ('B0036V9AGU', 4.277777777777778),
#               ('B008AF383S', 4.277777777777778),
#               ('B003LR7ME6', 4.277777777777778)],
#              'A31ICLWQ9CSHRS': [('B000TG4BA0', 5),
#               ('B0012GK3MQ', 5),
#               ('B0007U00X0', 5),
#               ('B00007E7JU', 4.728074209622652),
#               ('B000HJPK2C', 4.6850574712643684)],
#              'A2NB2E5DXE319Z': [('B004HD4L1U', 5),
#               ('B005Y1CYSQ', 5),
#               ('B00466X9SY', 5),
#               ('B007C8GMPU', 5),
#               ('B004KPLNO8', 5)],
#              'A1MCH5RXDOH87H': [('B009WE65EA', 3.8571428571428577),
#               ('B0096JZRBI', 3.1904761904761907),
#               ('B00622AG6S', 3.1904761904761907),
#               ('B0036AWR8E', 3.1904761904761907),
#               ('B008RW6R9Q', 3.1904761904761907)],
#              'A2JWF9IG8PJAOA': [('B002ZCXJZE', 5),
#               ('B005LDLP8W', 5),
#               ('B005CT56F8', 5),
#               ('B002YU83YO', 4.878183831672204),
#               ('B005FVNGRI', 4.761904761904762)],
#              'A28UMA3GW9L124': [('B002UUPWP6', 4.692631578947369),
#               ('B00015Y0FK', 4.514468085106383),
#               ('B0002WPREU', 4.363076923076923),
#               ('B004WOBCWU', 4.332857142857144),
#               ('B0054U6CEE', 3.9602343862265807)],
#              'A27QXQQOLAMRRR': [('B007Y4TTWU', 4.9837914023960534),
#               ('B006NNWZSI', 4.970729751403368),
#               ('B003L1ZYZ6', 4.649140546006067),
#               ('B00J238GV6', 4.531266149870801),
#               ('B0041L3JS4', 4.1113831089351285)],
#              'A2UEB48LAWFUCW': [('B007C8GMPU', 4.882408724513988),
#               ('B00966OWKI', 4.228501228501228),
#               ('B00BWL33H8', 3.947919065781952),
#               ('B0017JY5FE', 3.864864864864865),
#               ('B005TDWSJ4', 3.864864864864865)],
#              'A1G650TTTHEAL5': [('B00AJG3NK4', 5),
#               ('B00GJFGDUQ', 5),
#               ('B00LGQ6HL8', 5),
#               ('B00GAXEUOS', 5),
#               ('B00AANQLRI', 5)],
#              'A20DDH4NT6Q1E8': [('B002ZLOR38', 5),
#               ('B009JPBPWO', 5),
#               ('B005AWYB2Q', 5),
#               ('B004F9P2KU', 5),
#               ('B00480OTHI', 5)],
#              'A2ARDVMUGDFED6': [('B002TMRZOQ', 5),
#               ('B0001FTVE0', 5),
#               ('B001S0RUFY', 5),
#               ('B000KO0GY6', 5),
#               ('B007WTAJTO', 5)],
#              'A5GPH59NDWJRB': [('B00EVWX8R0', 4.80267558528428),
#               ('B005I6EU48', 4.427548985717281),
#               ('B00EZ9XKCM', 3.9565217391304346),
#               ('B0002Y5WZM', 3.9565217391304346),
#               ('B005D5M19U', 3.9565217391304346)],
#              'A1BJOHHLG0D965': [('B0036VO6IC', 5),
#               ('B001FWBUUG', 4.974662175789122),
#               ('B002VPE1Y8', 4.583333333333333),
#               ('B004CLYEDC', 4.542397616043658),
#               ('B002VPE1YS', 4.390296821411298)],
#              'A2ME89MSWVG9NF': [('B00ER52ES0', 4.644661054497121),
#               ('B004T9RR6I', 3.860091918447064),
#               ('B005JXADTG', 3.6325611325611327),
#               ('B00AO1L1RG', 3.5135135135135136),
#               ('B004YIZWYI', 3.5135135135135136)],
#              'A5JLAU2ARJ0BO': [('B00BZC31WQ', 5),
#               ('B00008I9K8', 4.379344986939923),
#               ('B00003006R', 4.331329113924051),
#               ('B003ZSHNGS', 4.1632883544473325),
#               ('B00004VX3T', 3.9438291139240507)],
#              'A3MUSWDCTZINQZ': [('B00A3YDPWS', 5),
#               ('B009WZRAQQ', 4.657923743831707),
#               ('B008ULPAT2', 4.639915176832224),
#               ('B009YQ8BTI', 4.613170389775969),
#               ('B00HRQB28Y', 4.592035965227713)],
#              'ABSYIF0ONC2AF': [('B0055CAR7Y', 4.9393939393939394),
#               ('B00328HR76', 4.573057305730573),
#               ('B004ELA0SS', 4.489451925512332),
#               ('B005CLPP8E', 4.121186390509023),
#               ('B004YKXGIK', 4.115864527629233)],
#              'A1AQ8JT2A3UWMY': [('B001G5ZTLS', 4.428571428571429),
#               ('B0057QETGS', 4.0),
#               ('B008NCD2EI', 4.0),
#               ('B004Z57WDO', 4.0),
#               ('B00493QWB0', 4.0)],
#              'A15XI2BEGGFEOW': [('B008DWCRQW', 5),
#               ('B004CLYEDC', 4.782272359044943),
#               ('B00006B9H8', 4.571428571428571),
#               ('B0032JPDFI', 4.571428571428571),
#               ('B003Y74AXO', 4.571428571428571)],
#              'A2JE071UW97J2A': [('B004MF11MU', 5),
#               ('B002KETE24', 5),
#               ('B001G5ZTZO', 5),
#               ('B003EYV224', 5),
#               ('B00017LSPI', 4.878787878787879)],
#              'A2X78O6G89CB30': [('B002WE6D44', 4.955319026180145),
#               ('B002GYPS3M', 4.764705882352941),
#               ('B002K3Z3DO', 4.764705882352941),
#               ('B003SQEAY0', 4.764705882352941),
#               ('B001G445Q4', 4.764705882352941)],
#              'A3N4VTNFPMTHEF': [('B00K91DB7Y', 5),
#               ('B003VANOI6', 5),
#               ('B000BTL0OA', 5),
#               ('B0058NN6CS', 4.878201611130481),
#               ('B00C28L138', 4.791428571428571)],
#              'A3LDLV1GWQJLEQ': [('B004R929AY', 5),
#               ('B000N99BBC', 5),
#               ('B00EOE4G4E', 5),
#               ('B004GUT1QO', 5),
#               ('B00829TIEK', 4.9410983833896855)],
#              'AQIJ3ZEEVCIKU': [('B001P05NBA', 4.832813353623246),
#               ('B001OI2YNS', 4.823822727520391),
#               ('B000HPV3RW', 4.592718540702092),
#               ('B005O88CUS', 4.5754985754985755),
#               ('B000IJY8DS', 4.478213507625273)],
#              'A3DOPYDOS49I3T': [('B009A6CZ30', 5),
#               ('B00CB2F65O', 5),
#               ('B0050A1O5U', 5),
#               ('B00168BSEW', 5),
#               ('B00FH66AW4', 4.927059117451202)],
#              'AFFVUZEGP1FDQ': [('B002LLJJAS', 4.242473617034633),
#               ('B00829THK0', 4.206763185352469),
#               ('B002C1BHIO', 4.124060150375939),
#               ('B00DTZYHX4', 4.082565663500161),
#               ('B00IX2VGFA', 3.9597273415796366)],
#              'AEZJTA4KDIWY8': [('B000FIVDIA', 5),
#               ('B001ID829O', 5),
#               ('B006EWUO22', 5),
#               ('B003ES5ZUU', 4.7144314482434435),
#               ('B001EYV690', 4.317073170731708)],
#              'A2J8T58Z4X15IO': [('B0063E3ZPO', 5),
#               ('B001NJ0WCS', 5),
#               ('B00EZ9XGGC', 5),
#               ('B00EJ8CKGG', 4.920454545454546),
#               ('B00BOHNYU6', 4.916812683851854)],
#              'A20OBCQWBKCGZT': [('B001DJ64D4', 5),
#               ('B0031ESKJA', 5),
#               ('B002VPDM2A', 5),
#               ('B002MCZJ78', 5),
#               ('B0012GQZZU', 4.91304347826087)],
#              'AI2AOCTC8BQVZ': [('B004QK7HI8', 5),
#               ('B0077V88V8', 4.785714285714286),
#               ('B004T9Y0MW', 4.785714285714286),
#               ('B005O88CUS', 4.785714285714286)],
#              'A3W4D8XOGLWUN5': [('B0097BEF1S', 4.508333333333333),
#               ('B00BOHNYTW', 4.389754008492934),
#               ('B000A3WS16', 4.296238758943614),
#               ('B003AM8S3G', 4.211082945964747),
#               ('B001FA1NUK', 4.08)],
#              'A1F9Z42CFF9IAY': [('B000053HC5', 4.41678520625889),
#               ('B001FA09WI', 4.261874197689345),
#               ('B000H4CLXS', 4.2212768719438305),
#               ('B00ATM1MHO', 4.218263696902012),
#               ('B002EEP3MK', 4.138420238300029)],
#              'A15TABNGK6L4N3': [('B004W2JKWG', 5),
#               ('B00005T3G0', 4.857142857142857),
#               ('B002DW96M6', 4.857142857142857),
#               ('B00AW54Z7C', 4.857142857142857),
#               ('B004Z0S6RU', 4.857142857142857)],
#              'A8FKL1DHTHC12': [('B0062EUE54', 5),
#               ('B0043RS864', 5),
#               ('B00139W0XM', 4.95),
#               ('B0090XWU8S', 4.783663366336634),
#               ('B001CCAISE', 4.4543478260869565)],
#              'A1X2LENOF84LCQ': [('B0010WG2H2', 4.081392995719807),
#               ('B000Q8UAWY', 3.5808231558152688),
#               ('B009O7XUW0', 3.472742279086329),
#               ('B001PUQ7PG', 3.4525517763801257),
#               ('B003ZQYVVK', 3.284075573549258)],
#              'A356RFKNIG043B': [('B0082E9K7U', 4.620783181919188),
#               ('B0085YTCYS', 4.1494708994708995),
#               ('B003M0NURK', 4.00974025974026),
#               ('B00BD7UVO4', 3.9642857142857144),
#               ('B0043EV20Q', 3.9642857142857144)],
#              'AJEOFP6ZWY0MK': [('B005FYNSPK', 5),
#               ('B00017LSPI', 4.757797270955166),
#               ('B0041Q38NU', 4.682794109961358),
#               ('B001XURP7W', 4.6395695437631135),
#               ('B00ATM1MGA', 4.526315789473684)],
#              'A2L9OPJAAEK08Q': [('B00BB5ZQC0', 3.769230769230769),
#               ('B008CXTX7S', 3.6666666666666665),
#               ('B0002IOIMQ', 3.6666666666666665),
#               ('B002MUGUFK', 3.6666666666666665),
#               ('B0042X93B8', 3.6666666666666665)],
#              'AO2EURP2Y4JZM': [('B004CLYE8C', 4.625098522406719),
#               ('B002K9IHGI', 4.156364027567295),
#               ('B00829TIEK', 4.141040489209969),
#               ('B003YTPP72', 4.009951956074125),
#               ('B00511PS3C', 3.935483870967742)],
#              'A23ZNGL704AW7O': [('B00119T6NQ', 4.810741645679537),
#               ('B001E1Y5O6', 4.663489202939301),
#               ('B004T1YAEI', 4.606752730883813),
#               ('B004CLYEFK', 4.594488984318686),
#               ('B00HZ9GNGY', 4.421052631578947)],
#              'A3EQQHWJ1EEYEU': [('B002IWP87S', 5),
#               ('B000LRMS66', 5),
#               ('B00834SJSK', 4.968675934789861),
#               ('B00484IEJS', 4.842105263157895),
#               ('B004G6002M', 3.35934664246824)],
#              'A2JOPUWVV0XQJ3': [('B00212NO6W', 5),
#               ('B001TH7GSW', 4.312976579101445),
#               ('B00DIFIM36', 3.8307873090481785),
#               ('B005X1Y7I2', 3.6956521739130435),
#               ('B009IBX7Z2', 3.6956521739130435)],
#              'A33HIV8RXRDM88': [('B00EOE4G4E', 5),
#               ('B002P3KH80', 5),
#               ('B00A8FCX8E', 5),
#               ('B002VPE1X4', 4.793362717137672),
#               ('B009YT6PPC', 4.759258821827593)],
#              'A37CEYB95LK6R6': [('B000CRFOMK', 5),
#               ('B004SBBD8U', 4.968379446640316),
#               ('B0056TYRMW', 4.816864295125165),
#               ('B004S4R5CK', 4.695652173913044),
#               ('B00429N18S', 4.695652173913044)],
#              'AM8W6Y3HVXLZT': [('B003BLQHN4', 4.981481481481481),
#               ('B001U0O5QE', 4.4338624338624335),
#               ('B002YU83YO', 4.406009649010546),
#               ('B001OMH1JQ', 3.814814814814815),
#               ('B000HKIPVE', 3.814814814814815)],
#              'A2PSD2R9A1CXG7': [('B0012Y2LLE', 4.872716559010087),
#               ('B007BXD66E', 4.863316894670757),
#               ('B00009XVBY', 4.8),
#               ('B00CGWNKVQ', 4.770922770928138),
#               ('B008R6WUZC', 4.530651089528985)],
#              'A27B1U3OWCU14J': [('B001C4ETU0', 4.2592592592592595),
#               ('B0018O9JIG', 4.2592592592592595),
#               ('B001MPWMDA', 4.2592592592592595),
#               ('B004ZMV2GA', 4.2592592592592595),
#               ('B000FBK3QK', 4.2592592592592595)],
#              'ALQ4USPEQ9L5N': [('B009YQ8BTI', 4.6724166833703356),
#               ('B006T7KQDO', 4.614542546201593),
#               ('B0043M668G', 4.511012354389806),
#               ('B008ULPAT2', 4.392990238072285),
#               ('B00DQZPCTA', 4.376531605101001)],
#              'A2HRHF83I3NDGT': [('B001CIREXA', 5),
#               ('B001AW8W7A', 5),
#               ('B00CDIK908', 5),
#               ('B002RM08RE', 5),
#               ('B003690Q42', 5)],
#              'A1MFPAM9TTRTXN': [('B002HWRJY4', 5),
#               ('B000067RC4', 5),
#               ('B007WTAJTO', 5),
#               ('B003SX0OR0', 4.809523809523809),
#               ('B001TQ2PSO', 4.809523809523809)],
#              'A20WUUD9EDWY4N': [('B003T0EYVE', 5),
#               ('B009BZX340', 4.777777777777778),
#               ('B00004ZC8Y', 4.777777777777778),
#               ('B004MYFOE2', 4.777777777777778),
#               ('B005CTKYB4', 4.777777777777778)],
#              'AWNJAY0M5UI70': [('B005OFFH5Y', 5),
#               ('B001TH7GUU', 5),
#               ('B005HMKKH4', 4.727972929938784),
#               ('B00DTPYRKC', 4.657894736842105),
#               ('B003VAGXZC', 4.657894736842105)],
#              'A2WW57XX2UVLM6': [('B001T9NX9Q', 5),
#               ('B00EAR8S76', 5),
#               ('B002G1YPH0', 5),
# ...
#               ('B005KQ0S8S', 4.538461538461538)],
#              'A186697K4XKXQL': [('B00E0HITQ6', 4.8689075630252105),
#               ('B003FST9EC', 4.48869696721643),
#               ('B00FJRS5BA', 4.452999087026251),
#               ('B0017TFVUW', 4.448051948051948),
#               ('B005HY4UJ6', 4.353970589975544)],
#              'A11LNPG39A2ZV4': [('B0012GQZZU', 4.9639423076923075),
#               ('B000LRMS66', 4.9639423076923075),
#               ('B00BOHNYU6', 4.557046383506045),
#               ('B00AXVXXNC', 4.524815641911629),
#               ('B00BOHNYTW', 4.3076923076923075)],
#              'APGQTZZ4ZFPHO': [('B000CKVOOY', 5),
#               ('B0051FWA7U', 4.454545454545454),
#               ('B000WKW69Q', 4.454545454545454),
#               ('B001542X64', 4.454545454545454),
#               ('B005FUNYSA', 4.454545454545454)],
#              'A2OTQMC69J8MUI': [('B000M2TAN4', 5),
#               ('B008OHNZI0', 4.428571428571429),
#               ('B00D6XSRL2', 4.428571428571429),
#               ('B002MUYOLW', 4.428571428571429),
#               ('B002SZEOLG', 4.428571428571429)],
#              'A33SX0AD5PYD9B': [('B003ES5ZUU', 4.753287315177446),
#               ('B00GRNUO2I', 4.5265850945495),
#               ('B003M0NT1M', 4.5265850945495),
#               ('B0081FLFQE', 4.494422671088333),
#               ('B00JZM7TKI', 4.360812425328555)],
#              'A24QFMD1RXLJMB': [('B0055QYJIS', 4.142857142857143),
#               ('B00007IFED', 4.142857142857143),
#               ('B002ISXBFI', 4.142857142857143),
#               ('B005DSPLC6', 4.142857142857143),
#               ('B005FYNSPK', 4.142857142857143)],
#              'A2294LS59GC5K7': [('B002J9HBIO', 5),
#               ('B000UWX70S', 4.875),
#               ('B002V88HFE', 4.821532665603538),
#               ('B009DJ1THW', 4.766666666666667),
#               ('B00AAIPT76', 4.537878787878788)],
#              'A313H6238N589': [('B000HPV3RW', 4.0588235294117645),
#               ('B007WTAJTO', 4.0588235294117645),
#               ('B000VR3P9K', 4.0588235294117645),
#               ('B0016OEV7C', 4.0588235294117645),
#               ('B001SER48S', 4.0588235294117645)],
#              'A1XB7JGJ459ERP': [('B00DR0PDNE', 5),
#               ('B009SYZ8OC', 4.9447408166258775),
#               ('B00BGGDVOO', 4.7367349373736385),
#               ('B000CRFOMK', 4.660413931642988),
#               ('B00005LB8P', 4.631578947368421)],
#              'AR6APXLK7TJU2': [('B0002Y5WXE', 5),
#               ('B005TDWSF8', 4.523809523809524),
#               ('B00009KH63', 4.523809523809524),
#               ('B00829TIA4', 4.523809523809524),
#               ('B00009UTLM', 4.523809523809524)],
#              'AOEAD7DPLZE53': [('B00BW6KCTU', 4.86834319733325),
#               ('B002WE4HE2', 4.751692575725961),
#               ('B007WTAJTO', 4.699267604114696),
#               ('B000JMJWV2', 4.568902273985361),
#               ('B004G6002M', 4.43915343915344)],
#              'A2D0CO1OA6DSWY': [('B002DPUUKK', 4.608819345661451),
#               ('B005A0B7CA', 4.473684210526316),
#               ('B004M8SWBU', 4.473684210526316),
#               ('B004HW7KF0', 4.473684210526316),
#               ('B000CLNHXY', 4.473684210526316)],
#              'A3K91X9X2ARDOK': [('B00E98O7GC', 5),
#               ('B00CALM17C', 4.8606805561431985),
#               ('B00829TIEK', 4.654949341816191),
#               ('B003YKG2W8', 4.648242968868457),
#               ('B0058D8D94', 4.258064516129032)],
#              'A3SL0HA6422W4M': [('B0053R0WWG', 4.792592592592593),
#               ('B006MA9XXM', 4.4981481481481485),
#               ('B0094S360U', 4.266666666666667),
#               ('B00ENZRS76', 4.266666666666667),
#               ('B001UE6I0G', 4.266666666666667)],
#              'ARX7Z3NI6O0F7': [('B000KO0GY6', 5),
#               ('B000AZ57M6', 4.840217391304348),
#               ('B002YTDE5I', 4.831884057971014),
#               ('B0002GDIII', 4.565217391304348),
#               ('B0000X0VCY', 4.565217391304348)],
#              'A296QED1MV1V0J': [('B004Y1AYAC', 4.3690398399636505),
#               ('B0045KGZOG', 4.363333333333333),
#               ('B00BOZ1Y46', 4.083333333333333),
#               ('B00889ST2G', 4.083333333333333),
#               ('B00BI9X7UC', 4.083333333333333)],
#              'A3VBZDYGHF4NK8': [('B004DMNT2W', 5),
#               ('B001PUQ7PG', 5),
#               ('B002FYL7PG', 5),
#               ('B00BWHILCY', 5),
#               ('B002I3OZ6W', 5)],
#              'A1C5WS021EL3WO': [('B000ENUCR4', 5),
#               ('B007KXI2R8', 5),
#               ('B006Y0YZZ6', 4.984415584415585),
#               ('B008ZGKWQI', 4.925970414330054),
#               ('B001E1Y5O6', 4.923191109705928)],
#              'A2XU6J41ZQOJ2V': [('B003ES5ZUU', 5),
#               ('B003M2YT96', 5),
#               ('B002PHLZE6', 4.620689655172414),
#               ('B00109Y2DQ', 4.620689655172414),
#               ('B003L62T7W', 4.620689655172414)],
#              'A22R9L5DAVYYWR': [('B000OGX5AM', 4.430303030303031),
#               ('B000JMJWV2', 4.430303030303031),
#               ('B001IEXU68', 3.7333333333333334),
#               ('B000FKP7TY', 3.7333333333333334),
#               ('B000CDLCGG', 3.7333333333333334)],
#              'A24P4E3RJ6AX94': [('B002BH3Z8E', 5),
#               ('B00CTUIT20', 5),
#               ('B00GTGETFG', 5),
#               ('B000067RT6', 4.9432673106105245),
#               ('B003VAHYNC', 4.736792893875643)],
#              'A35C2IVVQR1HTK': [('B002HJ9PTO', 4.615384615384615),
#               ('B0007N55NM', 4.115384615384615),
#               ('B0012Y6HC8', 4.115384615384615),
#               ('B003PBB4ME', 4.115384615384615),
#               ('B001L6LG5K', 4.115384615384615)],
#              'A3GQY0TFRG0MPZ': [('B003VANO7C', 5),
#               ('B000JE7GPY', 5),
#               ('B004RFBIUU', 4.971137521222411),
#               ('B00FFJ0HUE', 4.842105263157895),
#               ('B0031ESKJA', 4.842105263157895)],
#              'A2SZLNSI5KOQJT': [('B004SBCFLE', 4.620512820512821),
#               ('B002SZEOLG', 4.528605645074955),
#               ('B0079UAT0A', 4.236157235278731),
#               ('B0076POAI0', 4.133333333333334),
#               ('B00COYOAYW', 4.133333333333334)],
#              'A33PVCHCQ2BTN0': [('B002TMRZOQ', 5),
#               ('B00BLGUKBQ', 5),
#               ('B004CLYEB4', 5),
#               ('B00006JN3G', 5),
#               ('B002Y6CJJ8', 5)],
#              'A2QNS95WGN35G9': [('B002J9HCV0', 5),
#               ('B001NEK2GE', 5),
#               ('B002BA596W', 4.6992674389296925),
#               ('B003X26LXW', 4.660012221382354),
#               ('B003RRYAXQ', 4.651930874750254)],
#              'A10O7THJ2O20AG': [('B002BH3Z8E', 5),
#               ('B0056TYRMW', 5),
#               ('B000ZD0CV4', 5),
#               ('B00E3W15P0', 5),
#               ('B000067RT6', 5)],
#              'A1WF4QNIE2Z3I7': [('B007R1FH3K', 4.738095238095238),
#               ('B00AEGRGNO', 4.5),
#               ('B00009UT9B', 4.5),
#               ('B005N3TPJQ', 4.5),
#               ('B007Q45EF4', 4.5)],
#              'A3S3VSXEFXBMRC': [('B001TH7GUU', 5),
#               ('B00479SVBU', 4.352941176470588),
#               ('B0046RE21G', 4.352941176470588),
#               ('B003XM73P2', 4.352941176470588),
#               ('B0015DYMVO', 3.917297612114152)],
#              'A1HBI9BBQIG1NH': [('B00DHPCVQG', 5),
#               ('B0096W1P6G', 4.915151515151515),
#               ('B004CLYEFK', 4.546643363167104),
#               ('B00EN27TCI', 4.211229946524064),
#               ('B00126R3P6', 4.181818181818182)],
#              'A1X1CEGHTHMBL1': [('B002SZEOLG', 5),
#               ('B001A4HAFS', 5),
#               ('B001FA1O18', 5),
#               ('B006FLENJC', 5),
#               ('B000TXEE14', 5)],
#              'A3T4OHEAHOJ700': [('B005BCCML2', 4.991217798594848),
#               ('B001DZJVO2', 4.781287485005997),
#               ('B006A93M7I', 4.752206809583859),
#               ('B008X9ZBVI', 4.748044626772648),
#               ('B00829TIEK', 4.652738569791149)],
#              'A324X7RVDAV3FT': [('B000IF51UQ', 4.3),
#               ('B000UE50O2', 4.3),
#               ('B000ZMCILW', 4.3),
#               ('B001BSQK8Q', 4.3),
#               ('B0000BZL1P', 4.3)],
#              'A10ZBR6O8S8OCY': [('B002TLTE6O', 5),
#               ('B00AQRUW4Q', 5),
#               ('B001N85NMI', 5),
#               ('B004HKJTT2', 5),
#               ('B00DLKE8C2', 5)],
#              'A28X0LT2100RL1': [('B002WE4HE2', 5),
#               ('B00BGGDVOO', 4.901947310183705),
#               ('B001TH7GUU', 4.885863241576489),
#               ('B000067RT6', 4.782491051632276),
#               ('B00006JN3G', 4.586932432911217)],
#              'A2SL5IW096Z2BL': [('B0052TIRQI', 4.260869565217392),
#               ('B002BH3Z8E', 4.260869565217392),
#               ('B00006B7DA', 4.260869565217392),
#               ('B0021AFZOI', 4.260869565217392)],
#              'A1H7Y5XKPGT0OS': [('B009P2S4G6', 4.539969834087482),
#               ('B009NHWVIA', 4.385442217495964),
#               ('B00212NO6W', 4.338731443994602),
#               ('B0097CXWUW', 4.241145565340489),
#               ('B00EOE4G4E', 4.128205128205129)],
#              'A11EXFO14WEJM1': [('B0081FLFQE', 5),
#               ('B00B46A1VC', 4.883736559139786),
#               ('B002JM1V6O', 4.825710961261223),
#               ('B00E87E1OM', 4.673539708048403),
#               ('B0040RWN0O', 4.612903225806452)],
#              'ABMN74TBW5UWE': [('B001F8SCRE', 5),
#               ('B002WE0QN8', 5),
#               ('B0040702HU', 4.521739130434782),
#               ('B007MYDWKW', 4.521739130434782),
#               ('B003547GRI', 4.521739130434782)],
#              'A3P69DTOXII004': [('B00CM1AANW', 4.5), ('B005EJH6Z4', 4.5)],
#              'AA8RBTN3J2F5H': [('B000V1PAWQ', 4.818181818181818),
#               ('B0058UUR6E', 4.818181818181818),
#               ('B004S4R5CK', 4.818181818181818),
#               ('B007BWTOHU', 4.818181818181818),
#               ('B0018DQYQ2', 4.818181818181818)],
#              'A22I55P15NSAOX': [('B00COF7DGS', 5),
#               ('B003ES5ZUU', 5),
#               ('B0045XV2CI', 4.940244217969713),
#               ('B004DMNT2W', 4.9150197628458505),
#               ('B00HHRP11C', 4.7166161839238026)],
#              'A1PVX61PRPVX27': [('B0019884K0', 4.923076923076923),
#               ('B004FPQJGK', 4.923076923076923),
#               ('B00609B3J2', 4.923076923076923),
#               ('B00B4GGW5Q', 4.923076923076923),
#               ('B003OBUJIK', 4.756410256410256)],
#              'AM0QLU79O05JR': [('B0055P9K38', 2.9444444444444446),
#               ('B00D02AHEO', 2.9444444444444446),
#               ('B0085VB8GQ', 2.9444444444444446),
#               ('B004G8QO8O', 2.9444444444444446),
#               ('B001EZYMF4', 2.9444444444444446)],
#              'A3M82NO6OU1FHS': [('B008U69LC4', 4.679027479840237),
#               ('B002HWRJBM', 4.666666666666667),
#               ('B005E1CGZC', 4.666666666666667),
#               ('B0093HKFYW', 4.666666666666667),
#               ('B008DWH00K', 4.666666666666667)],
#              'A11P105WVK5240': [('B0052YFYFK', 5),
#               ('B005L38VPC', 4.809523809523809),
#               ('B0002TPFTA', 4.809523809523809),
#               ('B004OVECU0', 4.809523809523809),
#               ('B00COF7DGS', 4.809523809523809)],
#              'A2OWR5G2OAQF7C': [('B00429N18S', 5),
#               ('B002IC0YLS', 5),
#               ('B00BWL33H8', 4.9945085842137935),
#               ('B007PTCFFW', 4.849017509161784),
#               ('B00109Y2DQ', 4.739399528556179)],
#              'A2Q7OJTVPIO2XH': [('B0000BZL1P', 5),
#               ('B0058G40O8', 4.738636363636363),
#               ('B005KEL4NI', 4.363636363636363),
#               ('B0074WDDN8', 4.363636363636363),
#               ('B0007Q9PWQ', 4.363636363636363)],
#              'A35HOUWHAYZZN6': [('B007PTCFFW', 4.658741258741259),
#               ('B004T9RR6I', 4.252185245770115),
#               ('B00834SJSK', 4.171044219048589),
#               ('B003HIXP9K', 4.117216770936506),
#               ('B0076POB8O', 4.076923076923077)],
#              'A1USYP4AXF5I1D': [('B0043VE28S', 4.416666666666667),
#               ('B003WV5DJC', 4.416666666666667),
#               ('B001XURP7W', 4.416666666666667),
#               ('B0017JY5FE', 4.416666666666667),
#               ('B003WOL4VK', 4.416666666666667)],
#              'A1PL7QILVQV3IF': [('B002MMY4WY', 4.71875),
#               ('B00140DBRY', 4.139802631578948),
#               ('B001TK3ACA', 4.004464285714286),
#               ('B004T9RR4A', 3.71875),
#               ('B001UGDMYY', 3.71875)],
#              'A5QDZEOIMQ4LW': [('B0015YRMXI', 5),
#               ('B004ZNA3UA', 5),
#               ('B003QKBVYK', 5),
#               ('B00CMEN95U', 5)],
#              'A33152QEGO2MZN': [('B000IJY8DS', 5),
#               ('B000A6PPOK', 4.791666666666667),
#               ('B004AZ38Z0', 4.791666666666667),
#               ('B007BJHETS', 4.791666666666667),
#               ('B001WB02Z4', 4.791666666666667)],
#              'A2BX8DDQGCCG2J': [('B001FA1O0O', 4.92),
#               ('B002VPE1Q6', 4.72),
#               ('B0009ZBRS0', 4.72),
#               ('B0011U65F2', 4.72),
#               ('B003T5KXJQ', 4.72)],
#              'A95PWI4S6WHGL': [('B00F3F0EIU', 4.631869827429216),
#               ('B001TI9F8U', 4.615384615384615),
#               ('B000K4V4X8', 4.615384615384615)],
#              'A3JV071KO43Q5X': [('B004QK7HI8', 4.611111111111111),
#               ('B004T9RR6I', 4.165047382517782),
#               ('B00DSUTVK4', 4.111111111111111),
#               ('B008JGR9MO', 4.111111111111111),
#               ('B00008SCFL', 4.111111111111111)],
#              'A28N2AWOVO2PB': [('B005KSAG3S', 5),
#               ('B004CLYEFK', 4.993925398881067),
#               ('B0088PPFP4', 4.886208470021451),
#               ('B002S0O7LI', 4.840843023255814),
#               ('B00E98O7GC', 4.740437726190083)],
#              'A14NA0W8ESGDSI': [('B0034CL2ZI', 4.958548034237438),
#               ('B00B4OCWE8', 4.799626746855981),
#               ('B002DUCMQU', 4.645339542710973),
#               ('B00F9ZQQ8Q', 4.625128205128205),
#               ('B001IWOBA4', 4.205128205128205)],
#              'A377LPVLLAI42D': [('B003SGCO3E', 3.6),
#               ('B004JWA70I', 3.6),
#               ('B000BWACX2', 3.6),
#               ('B000JVCPEY', 3.6),
#               ('B0015TJNEY', 3.0620689655172417)],
#              'A2MOD50IHEDH3G': [('B005TDWX2Q', 5),
#               ('B006EKIQYM', 4.6214010958523675),
#               ('B000N99BBC', 4.601918962769994),
#               ('B00DQZP7X6', 4.527900561050138),
#               ('B000CH3IIW', 4.290322580645161)],
#              'A1CMWB7AWQUQH4': [('B00505EZZ6', 3.8461538461538463),
#               ('B005CPGHAA', 3.8461538461538463),
#               ('B009ZIILLI', 3.8461538461538463),
#               ('B000VE2RP6', 3.6711538461538464)],
#              'A3NGOG8Z78AZSD': [('B004ELA0SS', 5),
#               ('B005A2RLXC', 4.444444444444445),
#               ('B00002EQCW', 4.444444444444445),
#               ('B0056VOM2U', 4.444444444444445),
#               ('B004YIZWG6', 4.444444444444445)],
#              'A2FHTXLKY1XJDB': [('B002IJ95ZM', 3.857142857142857),
#               ('B001AHALEC', 3.857142857142857),
#               ('B002GYPS3M', 3.857142857142857),
#               ('B002OOWB3O', 3.857142857142857),
#               ('B000UO6C5S', 3.857142857142857)],
#              'A1UNJ46NSB352E': [('B00D5Q75RC', 4.968808606916589),
#               ('B0046W5EQI', 4.838754863025616),
#               ('B00I053I5G', 4.59375),
#               ('B003MVZ60S', 4.59375),
#               ('B008D97LNE', 4.59375)],
#              'A1V5TRJXTI6F01': [('B00A83I8G2', 5),
#               ('B003DZ165W', 4.874705882352941),
#               ('B0037H8AB4', 4.764705882352941),
#               ('B004I5BUSO', 4.764705882352941),
#               ('B001UGMTKC', 4.764705882352941)],
#              'A2RIXSMGE9VIBG': [('B0097252UK', 4.0),
#               ('B000JV9LUK', 4.0),
#               ('B006JWMOOI', 4.0)],
#              'A2MCRCK1V61FWQ': [('B0009ZBRS0', 5),
#               ('B009W8YQ6K', 5),
#               ('B001NJ0D0Y', 5)],
#              'A2EMUM49CE0JV4': [('B000QUUFRW', 5),
#               ('B001GGAIGI', 4.636363636363637),
#               ('B00004ZCDD', 4.636363636363637),
#               ('B000NB05MO', 4.636363636363637),
#               ('B0058UUR6E', 4.636363636363637)],
#              ...})

# %%
uid= "A2EMUM49CE0JV4"
print(top_n[uid])
# Out:
# [('B000QUUFRW', 5), ('B001GGAIGI', 4.636363636363637), ('B00004ZCDD', 4.636363636363637), ('B000NB05MO', 4.636363636363637), ('B0058UUR6E', 4.636363636363637)]

# %% [markdown]
# 18. Recommending top five products in item based collaborative filtering

# %%
k=5
top_n = defaultdict(list)
def get_top_n(predictions, n=k):
    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

top_n = get_top_n(prediction_knnMeansII, n=k)
top_n
# Out:
# defaultdict(list,
#             {'A1Z7U9K6X3FEOU': [('B000VDCT3C', 5),
#               ('B003GSCS3U', 5),
#               ('B00834SJNA', 4.45945945945946),
#               ('B004Q81CKY', 4.428571428571429),
#               ('B002FYL7PG', 4.3076923076923075)],
#              'A18HE80910BTZI': [('B002MPPHKY', 5),
#               ('B00836H2BI', 5),
#               ('B00J238GV6', 4.666666666666667),
#               ('B003LPUWT0', 4.666666666666667),
#               ('B0066CHKMW', 4.5)],
#              'A1F1A0QQP2XVH5': [('B003CJTQJC', 5),
#               ('B00000K4KH', 5),
#               ('B00BQHD4B8', 5),
#               ('B00BOHNYU6', 5),
#               ('B000NK8EWI', 5)],
#              'ARBKYIVNYWK3C': [('B0015YJOK2', 5),
#               ('B004SBBD8U', 5),
#               ('B0052SCU8U', 5),
#               ('B000068MP2', 5),
#               ('B00007IFED', 5)],
#              'A2QDOJFFLFGF18': [('B00DQZQPNM', 5),
#               ('B00G4FCHH4', 5),
#               ('B00DQZRQPI', 5),
#               ('B0002L5R78', 4.924081132969951),
#               ('B005DOUJL8', 4.866932575789769)],
#              'A1VLE2SH9J8WYS': [('B0000510ZO', 4.945331287437118),
#               ('B0011U65F2', 4.927884615384615),
#               ('B005FYNSPK', 4.705743502181947),
#               ('B0015DYMVO', 4.6008202323991805),
#               ('B000F28DP2', 4.458333333333333)],
#              'A23NSKTMSPPBTR': [('B000LRMR26', 5),
#               ('B004UBU3SY', 5),
#               ('B004HIN7SI', 4.875),
#               ('B00562O8U0', 4.8),
#               ('B00546JKJC', 4.795430757405864)],
#              'A2NX6PABLIJLP1': [('B00119T6NQ', 5),
#               ('B00009EHJV', 4.9),
#               ('B0009S5HQA', 4.833333333333333),
#               ('B007OY5V68', 4.833333333333333),
#               ('B003LZYXYU', 4.666666666666667)],
#              'ABUE0ALHKWKHC': [('B002WE6D44', 5),
#               ('B004CLYEH8', 4.870284179072376),
#               ('B0082E9K7U', 4.857541779432363),
#               ('B00EAR8S76', 4.7530938630104025),
#               ('B005I6EU48', 4.647886325832966)],
#              'A37IRE9GZ0CZ7I': [('B005DKZTMG', 5),
#               ('B00CI3BIWQ', 5),
#               ('B005EOWBKE', 4.642857142857143),
#               ('B000067RC4', 4.5),
#               ('B002CMLDT6', 4.333333333333333)],
#              'A2HDTOF8222KN3': [('B00011KM38', 5),
#               ('B00007EDM8', 4.25),
#               ('B0015V1H28', 1)],
#              'AX7317G153T8W': [('B001FA1NZK', 5),
#               ('B0001DBEM4', 4.75),
#               ('B0002L5R78', 4.703278551969956),
#               ('B001E1Y5O6', 4.696945213388449),
#               ('B001DULYZG', 4.615384615384615)],
#              'A1RDHBBZE1NPS3': [('B00AEKEA48', 5),
#               ('B00BOHNYU6', 4.181297739167385),
#               ('B00829THK0', 4.113154382823216),
#               ('B0097BEFYA', 3.9351298600936797),
#               ('B008RK9V46', 3.9256756756756754)],
#              'A6XDZ1MJ0B1A2': [('B004ZNA3UA', 5),
#               ('B00D7P6176', 5),
#               ('B004XC6GJ0', 4.7407407407407405),
#               ('B004MU8VCS', 4.666666666666667),
#               ('B004XXMUCQ', 4.666666666666667)],
#              'AYMD77ITD15PT': [('B007IJ7UHC', 5),
#               ('B005QZ8BCI', 5),
#               ('B000031KIM', 5),
#               ('B00871SR68', 5),
#               ('B004CLYE8C', 4.566666666666666)],
#              'A781ITP3HE2N5': [('B003UT2E8E', 5),
#               ('B0012Y2LLE', 5),
#               ('B000FQ2JLW', 5),
#               ('B004I5FL1G', 4.8125),
#               ('B003ELYQGG', 4.607407407407408)],
#              'A2O6HZ2B9YSRXR': [('B001TH7T2U', 5),
#               ('B004EBUXHQ', 5),
#               ('B002VKVZ1A', 5),
#               ('B005X64OA8', 4.666666666666667),
#               ('B002SIMPXM', 4.05175897848783)],
#              'A1M7HP5CHDXXOU': [('B007471PZQ', 5),
#               ('B00829THH8', 4.7),
#               ('B00426C57O', 4.4),
#               ('B00EVIBN26', 4.042735042735043),
#               ('B00021XIJW', 2.0)],
#              'A1SX9PHJWTDMF9': [('B0029N3U8K', 4.857142857142857),
#               ('B0016OEV7C', 4.833333333333333),
#               ('B000O8I474', 4.8),
#               ('B00020S7XK', 4.7272727272727275),
#               ('B00007E816', 4.666666666666667)],
#              'AWPODHOB4GFWL': [('B00BB6LTI4', 5),
#               ('B00GR3FMXE', 5),
#               ('B000E5CYW8', 5),
#               ('B001TH7GT6', 4.999207468856781),
#               ('B00BERGFV6', 4.993944438227502)],
#              'A3QQGPI3CTV9SX': [('B000HZBR64', 5),
#               ('B0009S5HQA', 4.833333333333333),
#               ('B0000BZL1P', 4.814814814814815),
#               ('B0013AV4M4', 4.75),
#               ('B0013DXVYK', 4.666666666666667)],
#              'A31N0XY2UTB25C': [('B002SIMPXM', 5),
#               ('B002RYYZZS', 5),
#               ('B008C1JC4O', 5),
#               ('B003A7CDY6', 5),
#               ('B00DSUTVK4', 5)],
#              'A197T2N6RU7K56': [('B000N254LU', 5),
#               ('B00004ZCJE', 5),
#               ('B001QFZMBU', 5),
#               ('B001KB6Z2U', 5),
#               ('B00825BZUY', 5)],
#              'A3094EPI56GKZ6': [('B00FNPD1OY', 5),
#               ('B00829TIA4', 5),
#               ('B000HPV3RW', 5),
#               ('B00EL8NJ82', 5),
#               ('B008X9Z3UC', 4.951002711452384)],
#              'A680RUE1FDO8B': [('B0018P7WZ2', 5),
#               ('B000WKW69Q', 5),
#               ('B004CLYJ1Y', 5),
#               ('B0002CPBUK', 5),
#               ('B000E5CYW8', 5)],
#              'A3DGJMO6VPG6FJ': [('B002K42W50', 5),
#               ('B006W8U2MU', 5),
#               ('B00I6CVPVC', 5),
#               ('B00EO302SO', 5),
#               ('B002SQKL7Q', 4.870214752567693)],
#              'A2K5RRMPICZ606': [('B0019EHU8G', 5),
#               ('B00009R86L', 5),
#               ('B003ES5ZUU', 5),
#               ('B000ZSUQ9M', 4.5),
#               ('B0043EV20Q', 4.285714285714286)],
#              'A7EU2BWLLCJY2': [('B00HVMIL1U', 5),
#               ('B00ENZRS76', 5),
#               ('B006TL5KWC', 5),
#               ('B00EE1WUI6', 5),
#               ('B00F93IOR4', 5)],
#              'A2UOHALGF2X77Q': [('B0007LJHVA', 5),
#               ('B002LARRDK', 5),
#               ('B000068O34', 5),
#               ('B00065X51U', 5),
#               ('B002IKLJU0', 5)],
#              'A1EH2S92FHWZRP': [('B004SBBDD0', 5),
#               ('B000P1O73A', 5),
#               ('B002JCSV5I', 5),
#               ('B004JMZPJQ', 5),
#               ('B003ES5ZUU', 5)],
#              'A2QRXQPHDMFCQV': [('B009NB8WR0', 4.823529411764706),
#               ('B008O2HWTI', 4.666666666666667),
#               ('B005CWHZP4', 4.6),
#               ('B0035JJOLE', 4.5),
#               ('B007KZQM9G', 4.444016376856052)],
#              'A1OES7R7FDAT2L': [('B002VKVZ1A', 5),
#               ('B001PI9AAC', 5),
#               ('B005FYNSPK', 5),
#               ('B001MSU1FS', 5),
#               ('B005HMKKH4', 4.959203884985846)],
#              'ANRS196NKFVUU': [('B00001P4XH', 4.666666666666667),
#               ('B004TA0AUW', 4.6),
#               ('B000233WJ6', 4.5),
#               ('B0018M7ZES', 4.296238758943614),
#               ('B004S7Q8CA', 4.0)],
#              'AQM0K7MBBT4AY': [('B002K9IHGI', 5),
#               ('B00DBX371C', 5),
#               ('B008D1JRIO', 5),
#               ('B004CLYE8C', 5),
#               ('B00E3W15P0', 4.75)],
#              'A3VC74TJ06WDDD': [('B001NJ0D0Y', 5),
#               ('B003UH0Z9Q', 4.8),
#               ('B0090I9VVC', 4.6),
#               ('B00DR0PDNE', 4.595804195804195),
#               ('B007KZQM9G', 4.545454545454546)],
#              'ANW6EGY12V5XS': [('B002XN3OL4', 5),
#               ('B00G4E2IRE', 5),
#               ('B007SZ0EOW', 5),
#               ('B0001FTVE0', 5),
#               ('B003BKW2K2', 5)],
#              'ABIVKBMSIPEDY': [('B00836H2BI', 5),
#               ('B00894YWD0', 4.777777777777778),
#               ('B005X64OQ2', 4.666666666666667),
#               ('B009M3UT16', 4.666666666666667),
#               ('B00AR95FOU', 4.5245036547431745)],
#              'A2IMLOJ2Z2QEU2': [('B0035FZ12O', 5),
#               ('B005KAK2FI', 4.9),
#               ('B0002WPSBC', 4.754125412541254),
#               ('B005AWYB2Q', 4.75),
#               ('B003KPBRRW', 4.6)],
#              'AFICF7DKHTQ87': [('B000VJX7DW', 5),
#               ('B00HYAL84G', 5),
#               ('B00007E7QS', 4.666666666666667),
#               ('B00EYTM3DK', 4.5),
#               ('B00FRKOFIQ', 4.4)],
#              'A25KKXUQQ0OLWB': [('B008OIYDM6', 5),
#               ('B00HPM1G8Q', 5),
#               ('B0074BW614', 5),
#               ('B00E5UHRIO', 4.979303913085838),
#               ('B0088CJT4U', 4.669712604873072)],
#              'A2PJH18W4XHTZW': [('B001423GZO', 5),
#               ('B003L1ZYZ6', 5),
#               ('B0009K9FZW', 5),
#               ('B00A6288II', 5),
#               ('B002V88HFE', 4.906286979236983)],
#              'A2VJ5ALN1BIV3B': [('B000M2TAN4', 5),
#               ('B0002GRUV4', 4.666666666666667),
#               ('B007WTAJTO', 4.629458887642194),
#               ('B00466X9SY', 4.5),
#               ('B004KU0RJK', 4.428571428571429)],
#              'AR1T36GLLAFFX': [('B003ES5ZQE', 5),
#               ('B000BQ7GW8', 4.846153846153846),
#               ('B001MT8J4W', 4.666666666666667),
#               ('B002VPE1Z2', 4.1875),
#               ('B004Q3R9AQ', 2.763569455561588)],
#              'A35HNL2VEDK9Z1': [('B00BOZ1Y46', 5),
#               ('B000IV413S', 5),
#               ('B00007E89K', 5),
#               ('B00267S7TQ', 5),
#               ('B0009GZAGO', 5)],
#              'A4GGT6O0GQNV2': [('B00FNPD1OY', 5),
#               ('B007KXI2R8', 5),
#               ('B00D5Q75RC', 5),
#               ('B007R5YDYA', 4.948160535117057),
#               ('B004WO8HQ4', 4.625)],
#              'A2BLFCOPSMBOZ9': [('B00BB72WX4', 5),
#               ('B00HZWJGS8', 5),
#               ('B00CIZ2238', 5),
#               ('B009JBFOZW', 5),
#               ('B001TH7GUA', 5)],
#              'A100WO06OQR8BQ': [('B00434OWDA', 4.75),
#               ('B004VVLZN0', 4.714634146341464),
#               ('B000LP0R3E', 4.666666666666667),
#               ('B00CGYCOR0', 4.666666666666667),
#               ('B0009YJXMS', 4.625)],
#              'A3G7BEJJCPD6DS': [('B0028Y4H1O', 5),
#               ('B00HPM1G8Q', 4.671738557313044),
#               ('B0088CJT4U', 4.583945815093459),
#               ('B0016HZSJO', 4.5),
#               ('B0040702HU', 4.142857142857143)],
#              'A1CYTBE7LLUQ8F': [('B0002IWC9C', 5),
#               ('B004R7A9NU', 4.666666666666667),
#               ('B000EVLS4C', 4.454545454545454),
#               ('B00093IIRA', 4.388888888888889),
#               ('B007GMPZ9Q', 4.25)],
#              'AHROSV6WJOEGY': [('B0002CPBUK', 5),
#               ('B00006HMPK', 5),
#               ('B0007QKMQY', 4.634920634920634),
#               ('B0002GDIII', 4.5),
#               ('B002V8C3W2', 4.488175675675675)],
#              'A3FBM0RMCMAABV': [('B008X9Z44M', 5),
#               ('B00834SJSK', 5),
#               ('B00A6UYCT4', 4.892857142857143),
#               ('B002FB684E', 4.857142857142857),
#               ('B005I6EU48', 4.831430353646988)],
#              'A2X61KKXXR6WNP': [('B005KQ2O26', 5),
#               ('B004CLYEDC', 4.9556784659966695),
#               ('B0000UV2AW', 4.2),
#               ('B0000AKVHF', 4.166666666666667),
#               ('B001F7HLRC', 4.142857142857143)],
#              'AEJAGHLC675A7': [('B00267S7TQ', 5),
#               ('B002Y6CJJ8', 5),
#               ('B000NDBRJC', 5),
#               ('B008OIYDM6', 5),
#               ('B001S2PPT0', 5)],
#              'A2OBDNQ5ZYU1L8': [('B000WH6H1M', 5),
#               ('B005EWB396', 5),
#               ('B00212NO6W', 4.875),
#               ('B0019EHU8G', 4.8525035915831065),
#               ('B0038KV2MO', 4.801163785346701)],
#              'A3R19YKNL641X3': [('B00HR3J65I', 5),
#               ('B00DR6DQZA', 4.9536388158875155),
#               ('B00834SJSK', 4.9267915217539),
#               ('B00HFRWWAM', 4.803453165728856),
#               ('B006ZT4VA0', 4.8)],
#              'A28BX3MM90A6FI': [('B001EZ0K82', 5),
#               ('B007BXD66E', 4.916666666666667),
#               ('B004TJ6JH6', 4.893307048494017),
#               ('B001KBZ3QO', 4.8896103896103895),
#               ('B005FRI50K', 4.666666666666667)],
#              'A3NKRH3TJ4DPVI': [('B0001Y7UAI', 5),
#               ('B003ES5ZUU', 5),
#               ('B000F7QRTG', 5),
#               ('B000ONZTMW', 4.848484848484849),
#               ('B003WGJYCY', 4.75)],
#              'A30X750M8V1XXW': [('B0007WK8KS', 5),
#               ('B00D68Y9B4', 5),
#               ('B0002VAQR4', 5),
#               ('B001KUL012', 5),
#               ('B001XURPQI', 5)],
#              'AG5WSXI52FPKH': [('B000V0GXR8', 5),
#               ('B00E3W15P0', 4.75),
#               ('B000Q82PIQ', 4.733333333333333),
#               ('B002IO2UM2', 4.471153846153846),
#               ('B00008VF63', 4.4)],
#              'A2PREU4LOFQRB1': [('B000N99BBC', 5),
#               ('B000IV413S', 5),
#               ('B00GK22DF2', 5),
#               ('B001HN6CVA', 4.666666666666667),
#               ('B00FH66AW4', 4.623654054556292)],
#              'A3LGT6UZL99IW1': [('B000L47AHG', 5),
#               ('B00HFFDDLG', 5),
#               ('B004IK2EAW', 5),
#               ('B003YCOL56', 5),
#               ('B005NC8BF6', 5)],
#              'A2FRKEXDXDN1KI': [('B00BUJBHGG', 5),
#               ('B002ZIMEMW', 5),
#               ('B0088CJT4U', 4.779286405335873),
#               ('B0095F5AFG', 4.762762762762763),
#               ('B0002Y5WZC', 4.714285714285714)],
#              'A36K2N527TXXJN': [('B006W8U2MU', 5),
#               ('B001FN14RE', 5),
#               ('B000HPV3RW', 5),
#               ('B00AKONZ3U', 5),
#               ('B003FGH2TI', 5)],
#              'A1PSVZBM894R5H': [('B004I43F9C', 5),
#               ('B003CJTQJC', 4.857142857142857),
#               ('B000V4PZCI', 4.5),
#               ('B002LITT6U', 4.333333333333333),
#               ('B00007056H', 4.166666666666667)],
#              'A1DSRM2P0WGQNS': [('B001E25JOA', 5),
#               ('B00275EVAQ', 5),
#               ('B006TF3746', 4.706349206349206),
#               ('B000U6XE7U', 4.25),
#               ('B001AGM2VI', 4.2)],
#              'A18EA7MNLXP9H5': [('B0052SCU8U', 4.972222222222222),
#               ('B002Y6CJJ8', 4.75),
#               ('B000067RT6', 4.72),
#               ('B002V8C3W2', 4.682065217391305),
#               ('B0012YFXSW', 4.666666666666667)],
#              'A2X3L31KCXBHCL': [('B00BUER7EC', 5),
#               ('B000J47W12', 5),
#               ('B000JMJWV2', 4.716653827850826),
#               ('B0033A7K7A', 4.5),
#               ('B00BWL33H8', 4.428571428571429)],
#              'A1H98YV5K5BUX0': [('B000UMX7FI', 4.857142857142857),
#               ('B001EQ4BVI', 4.857142857142857),
#               ('B00004WCIC', 4.4),
#               ('B00093IIRA', 4.388888888888889),
#               ('B000EM8GDW', 4.333333333333333)],
#              'A2NQMVTQ4PVLL': [('B006H06TVG', 5),
#               ('B0088PUEPK', 5),
#               ('B000I23TTE', 5),
#               ('B008JJLW4M', 5),
#               ('B0064R9H2A', 4.967391304347826)],
#              'ABQWMANK4AR63': [('B0046TJG1U', 5),
#               ('B004LNXO28', 5),
#               ('B000652M6Y', 5),
#               ('B000HZBR64', 5),
#               ('B00AR95ESC', 5)],
#              'AP53MVRC8ZEW2': [('B004RFBIUU', 5),
#               ('B007SZ0EHE', 5),
#               ('B006YLTLUY', 5),
#               ('B000UHQVOW', 4.818181818181818),
#               ('B0041MY32Y', 4.763532763532763)],
#              'A1IU7S4HCK1XK0': [('B003S5SOLG', 5),
#               ('B003NR57BY', 5),
#               ('B00894YWD0', 5),
#               ('B000031KIM', 5),
#               ('B00DQZQPNM', 5)],
#              'A3077MQTAKOVFZ': [('B005FVNGRI', 5),
#               ('B001F7AHOG', 5),
#               ('B000136P8W', 5),
#               ('B005JACJ50', 4.8),
#               ('B000WG6XW6', 4.666666666666667)],
#              'ASHJAZC9OA9NS': [('B004E0ZLZQ', 5),
#               ('B0083WYFWG', 5),
#               ('B00CBCUS1G', 5),
#               ('B0030DL37I', 4.444444444444445),
#               ('B00092GM0Q', 4.285714285714286)],
#              'A1GQRGB8FGSLIZ': [('B00EVIBN8U', 5),
#               ('B0055CAR7Y', 5),
#               ('B00BQ4F9ZA', 5),
#               ('B003ES5ZUU', 4.907846139232338),
#               ('B000N99BBC', 4.8788623387900945)],
#              'A11YIHB6IW352W': [('B001K9BFB8', 5),
#               ('B000OGX5AM', 5),
#               ('B008HO9DK4', 5),
#               ('B001CY0P7G', 4.25),
#               ('B002QEBMAK', 4.125022789048554)],
#              'A84FLVDK2R5JF': [('B002TLTE6O', 5),
#               ('B001542UQW', 5),
#               ('B001TK3E44', 5),
#               ('B00486MH80', 5),
#               ('B000O8WE66', 5)],
#              'A1KD8NJPZ01R37': [('B003ZBZ64Q', 4.916666666666667),
#               ('B005FVDTAW', 4.666666666666667),
#               ('B000AP05BO', 4.166666666666667),
#               ('B002OB49SC', 4.0),
#               ('B0070UFMOW', 3.75)],
#              'A19FRW264WZTGP': [('B003M0NURK', 5),
#               ('B000Q8UAWY', 4.891364506457757),
#               ('B001S4OTS6', 4.884615384615385),
#               ('B003ULNA3K', 4.875),
#               ('B0063705PE', 4.8708114681946295)],
#              'A1JUBRIZMO0RJV': [('B004M8SCHO', 4.666666666666667),
#               ('B001FA1NZU', 4.5),
#               ('B00CD8ADKO', 4.3893056469194915),
#               ('B00AJHDZSI', 4.324969969528277),
#               ('B000A3WS16', 4.296238758943614)],
#              'A38KK0SZYEH5UD': [('B00009X3UA', 5),
#               ('B0019EHU8G', 4.854637873124416),
#               ('B008RVJJZG', 4.815789473684211),
#               ('B000VDF5RO', 4.75),
#               ('B0041OSQ9I', 4.7070938215102975)],
#              'A3SRDVCD2ATIIS': [('B000TKHBDK', 5),
#               ('B0025ZH43O', 4.470588235294118),
#               ('B002DUEBIC', 4.0),
#               ('B000067RT6', 3.981761518718319),
#               ('B002WE4HE2', 3.840930580071454)],
#              'A2FXBWR4T4OFQ': [('B000V06UHQ', 5),
#               ('B000LRMS66', 4.856140621265445),
#               ('B006LW0W5Y', 4.85),
#               ('B003WGJYCY', 4.75),
#               ('B0093F4ROI', 4.666666666666667)],
#              'A3QNX5KWHDV0GD': [('B00065AO0K', 5),
#               ('B0041Q38NU', 5),
#               ('B00889ST2G', 4.75),
#               ('B00007EDZG', 4.727272727272727),
#               ('B003ELOSIW', 4.642857142857143)],
#              'A2SH7OWE8QJYNC': [('B0073HSH8U', 4.6),
#               ('B00008W2LC', 4.428571428571429),
#               ('B007PJ4PKK', 4.317733990147783),
#               ('B00FC2R7ZC', 4.2),
#               ('B006DY3CRK', 4.142857142857143)],
#              'AHF4I1FSIHABC': [('B002WE0QN8', 5),
#               ('B00004ZC8Y', 4.934724464560947),
#               ('B0002Y5WZM', 4.8),
#               ('B0018BTPLK', 4.75),
#               ('B00139W0XM', 4.714285714285714)],
#              'AETQIN7OH0RL9': [('B0000BZL5A', 5),
#               ('B009B0MZ8U', 4.99252801992528),
#               ('B008JJLW4M', 4.842105263157895),
#               ('B0062XB9FE', 4.75),
#               ('B0007U00X0', 4.571428571428571)],
#              'ATS2855497V0I': [('B007I5JT4S', 4.97197830643246),
#               ('B000X38ZO2', 4.875),
#               ('B0010Y414Q', 4.875),
#               ('B0058FAYPI', 4.8141891891891895),
#               ('B002TOJXK8', 4.666666666666667)],
#              'A1E1LEVQ9VQNK': [('B00DDH4TYA', 5),
#               ('B009NHWVIA', 5),
#               ('B00DVEJA7G', 5),
#               ('B00E3FHXYO', 5),
#               ('B007VGGFZU', 5)],
#              'A2DG63DN704LOI': [('B00KVNY2KA', 5),
#               ('B00JTU88Y2', 5),
#               ('B00EYTM3DK', 5),
#               ('B00F0DD0I6', 5),
#               ('B00FDK99QS', 4.95316938958418)],
#              'A30UP2KKD5IQEP': [('B003ES5ZUU', 5),
#               ('B002K9IHGI', 4.909247404128601),
#               ('B008YDTRZ4', 4.8164101409801106),
#               ('B000N99BBC', 4.802847101789603),
#               ('B00EIF0E0Y', 4.8)],
#              'A2WPL6Y08K6ZQH': [('B00AEKEA48', 5),
#               ('B003ELOSIW', 5),
#               ('B001FN14RE', 5),
#               ('B00HC0ZDOE', 5),
#               ('B00EB7UIO6', 5)],
#              'A17UNMURMLX0ZE': [('B00834SJSK', 4.955935598710734),
#               ('B009NHWVIA', 4.895018997923486),
#               ('B008PWUS4I', 4.85),
#               ('B009YQ8BTI', 4.758398998532843),
#               ('B0079UAT0A', 4.715797951644176)],
#              'A1F7YU6O5RU432': [('B00BB72WX4', 5),
#               ('B002K9IHGI', 5),
#               ('B0078AFGW2', 5),
#               ('B002Y6CJJ8', 5),
#               ('B0044YPN0A', 5)],
#              'A2EHYCA29NSQLU': [('B00E3FHXYO', 5),
#               ('B0067SF63A', 5),
#               ('B0012MI7N2', 4.6),
#               ('B00691YKE6', 4.5),
#               ('B0056VOM2U', 4.333333333333333)],
#              'AVJORH3ACR2A5': [('B005TUQV0E', 5),
#               ('B00CGUMR2Q', 5),
#               ('B002B8WVVU', 5),
#               ('B000MX48VM', 4.592592592592593),
#               ('B008MDSWI4', 4.266666666666667)],
#              'AA95DWUI3ODU': [('B00HWMPRKM', 4.75),
#               ('B00KHA2DQM', 4.4),
#               ('B007P4VOWC', 4.375),
#               ('B00F3SOHNU', 4.25),
#               ('B0096YOQRY', 4.090909090909091)],
#              'AEWYUPCNDV7HY': [('B001DJ64D4', 5),
#               ('B002VPE1X4', 5),
#               ('B0046HAO40', 5),
#               ('B00119T6NQ', 5),
#               ('B001OOZ1X2', 4.909090909090909)],
#              'A2XX2A4OJCDNLZ': [('B0019EHU8G', 4.973572433094247),
#               ('B00GMTN96U', 4.970500293341475),
#               ('B0082E9K7U', 4.81938254971596),
#               ('B001B8CSQ4', 4.5),
#               ('B003XN24GY', 4.104425682544857)],
#              'A30JPZ9TZ7I61U': [('B00634PLTW', 5),
#               ('B00KJJW36G', 5),
#               ('B0097FZRYI', 5),
#               ('B009NHWVIA', 5),
#               ('B007W7PIZ6', 5)],
#              'A3EFSLEMHNPP6A': [('B003VANO7C', 5),
#               ('B004N627KS', 4.805555555555555),
#               ('B0045XV2CI', 4.7729468599033815),
#               ('B004T9RR4A', 4.666666666666667),
#               ('B002DW99H8', 4.538461538461538)],
#              'A2SH6A32BE6NEV': [('B00EOI2SR2', 5),
#               ('B0076NA716', 5),
#               ('B0081FLFQE', 5),
#               ('B000TS7I6C', 5),
#               ('B00F1CRTLK', 4.769230769230769)],
#              'AN9CP6J4JF91X': [('B00483WRZ6', 5),
#               ('B000KO0GY6', 5),
#               ('B000HDJT4S', 4.930273487761913),
#               ('B004M8SSZK', 4.824561403508772),
#               ('B005HMKKH4', 4.725238451841293)],
#              'A2SR7S6ZJJDGNB': [('B00DVFLJDS', 4.809378906049425),
#               ('B006JG2IPY', 4.75),
#               ('B007YUISN0', 4.75),
#               ('B002J9HBIO', 4.392857142857143),
#               ('B007P4VOWC', 4.375)],
#              'A1J87SYB3JPQWH': [('B00007GQLU', 5),
#               ('B000JLK5PK', 4.8),
#               ('B001G5ZTLS', 4.763532763532763),
#               ('B0036Q7MV0', 4.705882352941177),
#               ('B003TLSXMO', 4.4)],
#              'A1H4IVXNXWWBLV': [('B000TKHBDK', 4.75),
#               ('B000WL6YY8', 4.714285714285714),
#               ('B003MQWN40', 4.714285714285714),
#               ('B00067LYFW', 4.6),
#               ('B00AWKC0EC', 4.6)],
#              'AT28RL25Q2OLK': [('B00IJU0K2Q', 5),
#               ('B006TF37H8', 5),
#               ('B0090SLE30', 5),
#               ('B004XVN17G', 5),
#               ('B003ES5ZUU', 4.842316396730489)],
#              'ASCBJEPXTOU0V': [('B0054YQO5C', 5),
#               ('B00212NO6W', 5),
#               ('B0058UUR6E', 4.94063230642818),
#               ('B006WAGG14', 4.857142857142857),
#               ('B001RQ2YF0', 4.842436974789916)],
#              'A3V5F050GVZ56Q': [('B00CBCUS1G', 5),
#               ('B000067RT6', 5),
#               ('B008EQYRRY', 5),
#               ('B001QUA6R0', 5),
#               ('B004SBBD8U', 5)],
#              'A4IL0CLL27Q33': [('B00006HMPK', 5),
#               ('B007R5YDYA', 5),
#               ('B009YT6PPC', 4.817464549418155),
#               ('B003HFCDLY', 4.705882352941177),
#               ('B00829THK0', 4.606457598066089)],
#              'A3NG7X4APIV649': [('B001NLV4TQ', 5),
#               ('B005IA843W', 4.963636363636363),
#               ('B004CLYEDC', 4.951565082308887),
#               ('B001FA1O0O', 4.933333333333333),
#               ('B0094R4POC', 4.760290556900726)],
#              'A1MRRMHGV3PN5W': [('B00FG38L16', 5),
#               ('B000N99BBC', 5),
#               ('B004XNLR16', 5),
#               ('B0082OJ2VE', 5),
#               ('B005A0B7CA', 4.917929292929292)],
#              'A1U11IP6K6NHAK': [('B002JCSV5I', 5),
#               ('B00BA8596G', 5),
#               ('B00CMJZAOI', 5),
#               ('B00GQOZFNQ', 5),
#               ('B00BB6LTI4', 4.950310053239302)],
#              'AKBVYIIHWI04B': [('B00316263Y', 5),
#               ('B000N99BBC', 5),
#               ('B00D18U63O', 5),
#               ('B00609B3J2', 4.875),
#               ('B002MAPRYU', 4.666666666666666)],
#              'A1ZCSSCAGBCD49': [('B002TLTE7I', 5),
#               ('B00DTPYQBM', 4.99329273132845),
#               ('B001NTBVP0', 4.991666666666666),
#               ('B00BUJBHGG', 4.932977262461423),
#               ('B00AAHT8JC', 4.841491841491841)],
#              'A12R3YGEHW7D8G': [('B004CAHTCQ', 5),
#               ('B0099SMFVQ', 5),
#               ('B0019EHU8G', 5),
#               ('B00489SLEQ', 4.75),
#               ('B001XURP7W', 4.497647058823529)],
#              'A7EJERNB7IK3Z': [('B002Y6CJJ8', 5),
#               ('B000UIA6YM', 5),
#               ('B0006OCEFY', 5),
#               ('B000V1MLBE', 4.704761904761904),
#               ('B0001FTVE0', 4.545454545454546)],
#              'A362FM6FYA1SYS': [('B007SZ0E1K', 5),
#               ('B005ES0YYA', 5),
#               ('B0042X9L6A', 4.5),
#               ('B006TF37H8', 4.363636363636363),
#               ('B0000A1G05', 4.333333333333333)],
#              'A3TA1UJWRJF9NC': [('B000MX48VM', 4.592592592592593),
#               ('B0038W0K2K', 4.486111111111111),
#               ('B0056BPUQC', 4.25),
#               ('B00004T8R2', 4.090909090909091),
#               ('B0006I09OS', 3.8)],
#              'A38RMU1Y5TDP9': [('B005IMFX2K', 5),
#               ('B003U7SR0U', 5),
#               ('B00HIUL1JO', 5),
#               ('B001RCTA8I', 5),
#               ('B006OM75I8', 5)],
#              'A1VTCSCH8FFC76': [('B003FWEQDM', 5),
#               ('B003CK10DG', 5),
#               ('B002M3SOC4', 4.857142857142857),
#               ('B0035J7XG2', 4.833333333333333),
#               ('B003N7NMO8', 4.75)],
#              'A3FOSLM5G1BO63': [('B009T0NFXG', 5),
#               ('B005YQXMAK', 4.5),
#               ('B008E18PDG', 4.5),
#               ('B00825BZUY', 4.251042715242422),
#               ('B0094R4PBU', 4.187203178138166)],
#              'ASFP250F22MDZ': [('B001CZFJJO', 5),
#               ('B00007E7QS', 4.666666666666667),
#               ('B000F34FVM', 4.666666666666667),
#               ('B0079UAT0A', 4.496241148019757),
#               ('B000AAZQJU', 4.285714285714286)],
#              'A3SMD3T0QTN109': [('B00829THEG', 5),
#               ('B0053OLY9O', 5),
#               ('B0052SCTLI', 5),
#               ('B0042FZ50O', 5),
#               ('B009WG6LLA', 5)],
#              'AJL3U764D7NI3': [('B007SZ0E1K', 5),
#               ('B002G1YNQS', 4.8),
#               ('B00CDY0DSA', 4.75),
#               ('B000R5LWRI', 4.75),
#               ('B000CKVOOY', 4.666666666666667)],
#              'A145LBW8ZHF0TW': [('B00007M1TZ', 4.7272727272727275),
#               ('B001TOD7ME', 4.545454545454546),
#               ('B000067RC4', 4.5),
#               ('B009LL9VDG', 4.481481481481482),
#               ('B00113PUJQ', 4.4)],
#              'A9LNWA25IM2DX': [('B00192KCAG', 5),
#               ('B001E25JOA', 5),
#               ('B001F7AHXM', 5),
#               ('B005KQ2O26', 5),
#               ('B00DQHZYRI', 5)],
#              'ANTGGAQYPSWHF': [('B00829THEG', 4.960960960960961),
#               ('B0036Q7MV0', 4.705882352941177),
#               ('B004T9RR0E', 4.666666666666667),
#               ('B000OLDG60', 4.636363636363637),
#               ('B00966OWKI', 4.6)],
#              'AOWF9T81XMX2S': [('B0016XIQ1U', 5),
#               ('B00005U21H', 5),
#               ('B008EQZ25K', 4.957115009746589),
#               ('B001342KM8', 4.933566433566433),
#               ('B002RL875A', 4.9325)],
#              'A3GX0FAMEXV6FB': [('B005EOWBHC', 4.737662337662338),
#               ('B005B3VO24', 4.5),
#               ('B004G6002M', 4.5),
#               ('B002ZV51DI', 4.1),
#               ('B003VOW5WI', 3.8)],
#              'A2IFGGXG3YV3Y6': [('B00IXEZAEQ', 5),
#               ('B00DMS0GTC', 5),
#               ('B003ES5ZUU', 5),
#               ('B005BCCML2', 4.75),
#               ('B009WU5XUG', 4.625)],
#              'A1P0JSFW184ZXJ': [('B002TLTE6O', 5),
#               ('B004MSQZUU', 5),
#               ('B002I3OZB2', 5),
#               ('B00BWHILCY', 5),
#               ('B00EZ9XG62', 5)],
#              'A17BUUBOU0598B': [('B001U3Y6AQ', 5),
#               ('B000JO7PIM', 5),
#               ('B00BVQXGUI', 4.75),
#               ('B005TDWVTQ', 4.666666666666667),
#               ('B00AM4A87O', 4.6)],
#              'A36IHC0K68NS2': [('B00CRY250U', 5),
#               ('B003ZHV978', 4.914634146341464),
#               ('B004ROOCO0', 4.666666666666667),
#               ('B000BN94F8', 4.666666666666667),
#               ('B002LITT42', 4.333333333333333)],
#              'A7UPJYPAH73NC': [('B007JCNOHS', 5),
#               ('B005FDXF2C', 5),
#               ('B000YQ6DIS', 4.962566844919786),
#               ('B005GOINEK', 4.9373342984710025),
#               ('B0016BVKAQ', 4.861538461538461)],
#              'A3ER6ARJ23CIN8': [('B00G0OYHCW', 5),
#               ('B002U0KGEI', 5),
#               ('B001EAQTRI', 5),
#               ('B003UE52ME', 4.803932376918177),
#               ('B001E1Y5O6', 4.785801713586292)],
#              'A226VGZWOEBPGL': [('B000OLDG60', 5),
#               ('B007DC89OW', 5),
#               ('B00390JT1O', 5),
#               ('B0041OSQ9I', 4.884055037717849),
#               ('B002R5AM7C', 4.8428634834186575)],
#              'A11EYMH9UV9XG7': [('B001RHJ60K', 5),
#               ('B00CGWNKVQ', 4.888888888888889),
#               ('B0001VWHH2', 4.666666666666667),
#               ('B008C1JC4O', 4.611111111111111),
#               ('B003YKG2W8', 4.582417582417583)],
#              'AV8MDYLHHTUOY': [('B00CRY250U', 5),
#               ('B004CLYEDC', 5),
#               ('B00HFRWWAM', 5),
#               ('B00EAXRVLY', 4.982051963263724),
#               ('B0088CJT4U', 4.697810238150919)],
#              'A22S7D0LP8GRDH': [('B003ES5ZUU', 5),
#               ('B001U02JZ8', 5),
#               ('B007ZZ6OW6', 4.9991242651033705),
#               ('B009T0NFTA', 4.7175576653569475),
#               ('B0042FZ50O', 4.5565644717017015)],
#              'A25TNBMJ4ZO7RD': [('B0007Y791C', 4.714285714285714),
#               ('B0009Q4PH4', 4.666666666666667),
#               ('B00HLDFUM2', 4.333333333333333),
#               ('B004K1EZDS', 4.214285714285714),
#               ('B005N8W16U', 4.2)],
#              'A2HMF8ZR67BNZS': [('B00006I5J7', 5),
#               ('B003HFCDLY', 5),
#               ('B000J47W12', 5),
#               ('B001TH7GUA', 5),
#               ('B000BOLHH0', 5)],
#              'A35Q0RBM3YNQNF': [('B009A68TMQ', 5),
#               ('B00HPMCO4Q', 5),
#               ('B00L3YHF6O', 4.978313311261575),
#               ('B00G4V0QSK', 4.9127038525194795),
#               ('B00J5174TU', 4.854112206772348)],
#              'A314KKDIJWCNMV': [('B00108UNEY', 5),
#               ('B004M5H660', 5),
#               ('B004LSNF04', 5),
#               ('B008RM235I', 5),
#               ('B00011KM38', 5)],
#              'A3N4I2KRSMACW8': [('B005J2E2US', 5),
#               ('B00CALLZK6', 5),
#               ('B0010Y414Q', 4.875),
#               ('B003PHJJV6', 4.5),
#               ('B001X017G2', 4.333333333333333)],
#              'A2V1J3JT5OOZFO': [('B0049V0ZX8', 5),
#               ('B007R5YDYA', 5),
#               ('B00CEZBKTO', 5),
#               ('B000UKMZ94', 4.75),
#               ('B000WYVBR0', 4.666666666666667)],
#              'AKSFZ4G1AXYFC': [('B000FFISV8', 5),
#               ('B0067I4Z6O', 5),
#               ('B000068O16', 4.9),
#               ('B0019EHU8G', 4.8125),
#               ('B008XV7VTG', 4.8)],
#              'A3HR0ZZOFKQ97N': [('B007RMAS1K', 5),
#               ('B002MZUNXU', 5),
#               ('B00A4ZXE40', 5),
#               ('B00212NO6W', 5),
#               ('B0019EHU8G', 5)],
#              'AB094YABX21WQ': [('B002WE6D44', 5),
#               ('B00494XZ1Y', 5),
#               ('B004S76NH0', 5),
#               ('B000ANCPNM', 5),
#               ('B000O5N5AI', 4.888888888888889)],
#              'A3S3R88HA0HZG3': [('B0053R0WWG', 5),
#               ('B001L2MJO6', 5),
#               ('B00316263Y', 5),
#               ('B0079UAT0A', 5),
#               ('B00EDCF0MY', 5)],
#              'A1VLVWTLV3LVHR': [('B002J9HBIO', 4.392857142857143),
#               ('B001C4ETU0', 3.8),
#               ('B00065XSP8', 3.0)],
#              'A1A535TCGNMVPI': [('B00FZ9SMVU', 5),
#               ('B00G2HV3OM', 5),
#               ('B000BKJZ9Q', 5),
#               ('B0097CXWUW', 5),
#               ('B001DJ64D4', 5)],
#              'A23GFTVIETX7DS': [('B001FN14RE', 5),
#               ('B00175VDY4', 5),
#               ('B004HD4L1U', 5),
#               ('B009M3UT16', 5),
#               ('B003ES5ZUU', 5)],
#              'A15QYHQH80W30L': [('B000144I30', 5),
#               ('B000VJX7DW', 5),
#               ('B000EOSHGQ', 5),
#               ('B000144I2Q', 5),
#               ('B00009MDBQ', 5)],
#              'A2NN1KIYEM2SKS': [('B002GU5XKO', 5),
#               ('B007PJ4P4G', 5),
#               ('B008EQYRRY', 4.976735316552251),
#               ('B005FYNSPK', 4.942425007193842),
#               ('B0036V9AGU', 4.6923076923076925)],
#              'A31ICLWQ9CSHRS': [('B007WTAJTO', 5),
#               ('B0007U00X0', 5),
#               ('B009OZUPUC', 4.920792079207921),
#               ('B000TG4BA0', 4.854729301023307),
#               ('B000HJPK2C', 4.8125)],
#              'A2NB2E5DXE319Z': [('B0000B006W', 5),
#               ('B006DDT6JO', 5),
#               ('B004KPLNO8', 4.991071428571429),
#               ('B0000BZL1P', 4.941657794872207),
#               ('B001RQ2YF0', 4.842436974789916)],
#              'A1MCH5RXDOH87H': [('B009WE65EA', 5),
#               ('B000068MP2', 5),
#               ('B008RW6R9Q', 4.682539682539682),
#               ('B0036AWR8E', 4.666666666666667),
#               ('B00622AG6S', 4.45)],
#              'A2JWF9IG8PJAOA': [('B002YU83YO', 5),
#               ('B005LDLP8W', 5),
#               ('B005TUQV0E', 5),
#               ('B00B8L36A6', 5),
#               ('B006MRAVFE', 4.75)],
#              'A28UMA3GW9L124': [('B0002WPREU', 5),
#               ('B00015Y0FK', 5),
#               ('B0079M711S', 4.9),
#               ('B0054U6CEE', 4.666666666666667),
#               ('B006DEBYWU', 4.472741246681858)],
#              'A27QXQQOLAMRRR': [('B004QGXOOI', 5),
#               ('B00GO1UV4E', 5),
#               ('B003DC8D8I', 5),
#               ('B00005NIMJ', 4.857142857142857),
#               ('B006NNWZSI', 4.827831844378824)],
#              'A2UEB48LAWFUCW': [('B00GHY5F3K', 5),
#               ('B00005AW1X', 4.5),
#               ('B005A0B3FQ', 4.4),
#               ('B007C8GMPU', 4.333333333333333),
#               ('B00408GUNY', 4.2815585692409845)],
#              'A1G650TTTHEAL5': [('B00LGQ6HL8', 5),
#               ('B00AANQLRI', 5),
#               ('B009A68TMQ', 5),
#               ('B001XURP7W', 5),
#               ('B00CHH0JF0', 4.9875)],
#              'A20DDH4NT6Q1E8': [('B000QWEN5K', 5),
#               ('B004F9P2KU', 5),
#               ('B00480OTHI', 5),
#               ('B00CD8ADKO', 4.97681277098342),
#               ('B00EOI2SYK', 4.867315606356482)],
#              'A2ARDVMUGDFED6': [('B0053OLY9O', 5),
#               ('B000KO0GY6', 5),
#               ('B007WTAJTO', 5),
#               ('B002LTWDSK', 5),
#               ('B0001FTVE0', 4.945454545454546)],
#              'A5GPH59NDWJRB': [('B0027VT6V4', 5),
#               ('B000VX6XL6', 4.844298245614035),
#               ('B0002Y5WZM', 4.8),
#               ('B0011ZCDKS', 4.8),
#               ('B00EVWX8R0', 4.555555555555555)],
#              'A1BJOHHLG0D965': [('B000Q8UAWY', 5),
#               ('B002VPE1Y8', 5),
#               ('B00AJHDZSI', 4.940178668171224),
#               ('B00005T3G0', 4.907142857142857),
#               ('B005FE7URM', 4.8)],
#              'A2ME89MSWVG9NF': [('B00AWRPIWQ', 5),
#               ('B00ER52ES0', 4.666666666666667),
#               ('B00AO1L1RG', 4.2),
#               ('B00JP12170', 3.9000000000000004),
#               ('B004YIZWYI', 3.857142857142857)],
#              'A5JLAU2ARJ0BO': [('B00015GYU4', 5),
#               ('B0002IWC9C', 5),
#               ('B00003006R', 5),
#               ('B00005LENO', 5),
#               ('B0007QKMQY', 4.857142857142857)],
#              'A3MUSWDCTZINQZ': [('B009T0NFXG', 5),
#               ('B004LB4MZS', 5),
#               ('B009WZRAQQ', 4.621196016157843),
#               ('B00HRQB28Y', 4.545203317105445),
#               ('B009YQ8BTI', 4.531007280557661)],
#              'ABSYIF0ONC2AF': [('B0055CAR7Y', 5),
#               ('B004ELA0SS', 5),
#               ('B0018BQR84', 4.666666666666667),
#               ('B004YKXGIK', 4.6),
#               ('B000U5TUWE', 4.5)],
#              'A1AQ8JT2A3UWMY': [('B00007E89K', 5),
#               ('B004FA8NOQ', 4.9),
#               ('B00004RC2D', 4.714285714285714),
#               ('B004M8SCHO', 4.666666666666667),
#               ('B0002KVQBA', 4.571428571428571)],
#              'A15XI2BEGGFEOW': [('B00006B9H8', 5),
#               ('B0032JPDFI', 5),
#               ('B004CLYEDC', 4.882964268245892),
#               ('B001ELK2NY', 4.75),
#               ('B008DWCRQW', 4.48430230421673)],
#              'A2JE071UW97J2A': [('B000SMVQK8', 5),
#               ('B001G5ZTZO', 5),
#               ('B003EYV224', 4.909090909090909),
#               ('B00017LSPI', 4.84375),
#               ('B004MF11MU', 4.545454545454546)],
#              'A2X78O6G89CB30': [('B000J1H4VI', 5),
#               ('B003ES5ZUU', 5),
#               ('B00212NO6W', 4.875),
#               ('B002WE6D44', 4.827977621245781),
#               ('B002K3Z3DO', 4.8)],
#              'A3N4VTNFPMTHEF': [('B00C28L138', 5),
#               ('B0058NN6CS', 5),
#               ('B00AWRPIWQ', 5),
#               ('B0041OSQ9I', 5),
#               ('B0052WPUI8', 4.8)],
#              'A3LDLV1GWQJLEQ': [('B007PTCFFW', 5),
#               ('B00F19Q7AC', 5),
#               ('B000N99BBC', 5),
#               ('B00829TIEK', 4.980063949733367),
#               ('B0088CJT4U', 4.780597880844732)],
#              'AQIJ3ZEEVCIKU': [('B004U1Y3IU', 5),
#               ('B000IJY8DS', 5),
#               ('B001OI2YNS', 5),
#               ('B005DJNRQM', 5),
#               ('B001P05NBA', 5)],
#              'A3DOPYDOS49I3T': [('B004YQX0SK', 5),
#               ('B0001CNMFM', 5),
#               ('B00CB2F65O', 5),
#               ('B002HWRZ2K', 5),
#               ('B00FH66AW4', 5)],
#              'AFFVUZEGP1FDQ': [('B002LLJJAS', 4.577777777777778),
#               ('B002TOJXIA', 4.571428571428571),
#               ('B00IVPU5BK', 4.557155715571557),
#               ('B00829THK0', 4.4490112206459935),
#               ('B00G4V0QSK', 4.392526751164463)],
#              'AEZJTA4KDIWY8': [('B001ID829O', 4.875),
#               ('B0009YDP7W', 4.5),
#               ('B00024ENWU', 4.5),
#               ('B003ES5ZUU', 4.422670569697733),
#               ('B006EWUO22', 4.25)],
#              'A2J8T58Z4X15IO': [('B00BOHNYU6', 5),
#               ('B00486MH80', 5),
#               ('B00004ZCJE', 5),
#               ('B00F1CRTJM', 5),
#               ('B00E8CF0CE', 5)],
#              'A20OBCQWBKCGZT': [('B001DJ64D4', 5),
#               ('B00CD778LC', 5),
#               ('B00IVFDZBC', 5),
#               ('B005LIDMYM', 4.8),
#               ('B005276QS6', 4.7663464923969325)],
#              'AI2AOCTC8BQVZ': [('B0077V88V8', 4.75),
#               ('B004QK7HI8', 4.554125546839906),
#               ('B005O88CUS', 4.25),
#               ('B004T9Y0MW', 3.0)],
#              'A3W4D8XOGLWUN5': [('B0097BEF1S', 4.818181818181818),
#               ('B000BONJXU', 4.75),
#               ('B0013DXVYK', 4.666666666666667),
#               ('B003AM8S3G', 4.555555555555555),
#               ('B00006IW1X', 4.449149238536296)],
#              'A1F9Z42CFF9IAY': [('B00DBDM934', 5),
#               ('B00752VKFA', 5),
#               ('B001OTZ8DA', 5),
#               ('B0011Z44UA', 5),
#               ('B004TJ6JH6', 5)],
#              'A15TABNGK6L4N3': [('B004Z0S6RU', 5),
#               ('B00005T3G0', 4.8),
#               ('B000YBH4YU', 4.714285714285714),
#               ('B003HFCDLY', 4.705882352941177),
#               ('B006DLP7BM', 4.666666666666667)],
#              'A8FKL1DHTHC12': [('B00139W0XM', 4.947619047619048),
#               ('B001CCAISE', 4.9384768145920726),
#               ('B002NO7PWC', 4.916666666666667),
#               ('B0062EUE54', 4.875420875420875),
#               ('B00007E7JU', 4.859895750016036)],
#              'A1X2LENOF84LCQ': [('B0010WG2H2', 4.666666666666667),
#               ('B002DPUUKK', 4.5),
#               ('B009O7XUW0', 4.4),
#               ('B0055QZ216', 4.4),
#               ('B000NDA5E0', 4.25)],
#              'A356RFKNIG043B': [('B0082E9K7U', 5),
#               ('B00BUHXQWQ', 4.666666666666667),
#               ('B003VAHYNC', 4.6521739130434785),
#               ('B004VM1T5S', 4.583333333333333),
#               ('B00HSQAIQU', 4.416666666666667)],
#              'AJEOFP6ZWY0MK': [('B0041Q38NU', 5),
#               ('B00017LSPI', 5),
#               ('B0000BZL1P', 5),
#               ('B005FYNSPK', 4.846682560583138),
#               ('B0057OCDQS', 4.563909774436091)],
#              'A2L9OPJAAEK08Q': [('B0049V0ZX8', 5),
#               ('B001TH7GUK', 4.916666666666667),
#               ('B002WE6D44', 4.782608695652174),
#               ('B009F7IBZK', 4.6875),
#               ('B005TDWVTQ', 4.666666666666667)],
#              'AO2EURP2Y4JZM': [('B00JZM7TKI', 5),
#               ('B004CLYE8C', 5),
#               ('B0088PUEPK', 4.818181818181818),
#               ('B00511PS3C', 4.6),
#               ('B002Z2QDNE', 4.6)],
#              'A23ZNGL704AW7O': [('B00HZ9GNGY', 5),
#               ('B00H7PBWK8', 5),
#               ('B004CLYEFK', 4.914557097212038),
#               ('B001E1Y5O6', 4.8279069767441865),
#               ('B006SOLITY', 4.75)],
#              'A3EQQHWJ1EEYEU': [('B00834SJSK', 5),
#               ('B002IWP87S', 5),
#               ('B00484IEJS', 4.5),
#               ('B004G6002M', 4.5),
#               ('B000LRMS66', 4.444444444444445)],
#              'A2JOPUWVV0XQJ3': [('B000E5CYW8', 5),
#               ('B00DIFIM36', 4.8561643835616435),
#               ('B001TH7GSW', 4.847458337630491),
#               ('B005LJQNQU', 4.4),
#               ('B004UR16ES', 4.25)],
#              'A33HIV8RXRDM88': [('B004HKJTTC', 5),
#               ('B000CCUG64', 5),
#               ('B002VPE1X4', 5),
#               ('B00A8FCX8E', 5),
#               ('B00006JN3G', 4.7873171394645055)],
#              'A37CEYB95LK6R6': [('B002IWP87S', 5),
#               ('B000CRFOMK', 5),
#               ('B004SBBD8U', 4.931818181818182),
#               ('B004S4R5CK', 4.882352941176471),
#               ('B005LFT3GG', 4.75)],
#              'AM8W6Y3HVXLZT': [('B0053G6GI6', 5),
#               ('B003BLQHN4', 4.5625),
#               ('B007BYLKFW', 4.4),
#               ('B001OMH1JQ', 4.333333333333333),
#               ('B000JMJWV2', 4.201388888888888)],
#              'A2PSD2R9A1CXG7': [('B00DT04I9W', 5),
#               ('B0012Y2LLE', 5),
#               ('B008R6WUZC', 5),
#               ('B004GXAL42', 4.95932911405191),
#               ('B007BXD66E', 4.916666666666667)],
#              'A27B1U3OWCU14J': [('B002TLTE6O', 4.944444444444445),
#               ('B000S5Q9CA', 4.615384615384615),
#               ('B005HSDLCO', 4.571428571428571),
#               ('B000FBK3QK', 4.44),
#               ('B0018O9JIG', 4.133333333333334)],
#              'ALQ4USPEQ9L5N': [('B009T0NFXG', 5),
#               ('B00EL8NJ82', 5),
#               ('B009YQ8BTI', 4.835122598759036),
#               ('B009APBY0G', 4.625),
#               ('B00E5UHRIO', 4.602280450571381)],
#              'A2HRHF83I3NDGT': [('B005EWB396', 5),
#               ('B000WYVBR0', 5),
#               ('B00G500AE0', 5),
#               ('B001AW8W7A', 5),
#               ('B00CDIK908', 5)],
#              'A1MFPAM9TTRTXN': [('B001TQ2PSO', 5),
#               ('B007WTAJTO', 5),
#               ('B00B4GGW5Q', 4.857142857142857),
#               ('B002HWRJY4', 4.815444324013528),
#               ('B000067RC4', 4.5)],
#              'A20WUUD9EDWY4N': [('B009BZX340', 5),
#               ('B00004ZC8Y', 5),
#               ('B009O7YU56', 5),
#               ('B005LFT3GG', 4.75),
#               ('B003T0EYVE', 4.75)],
#              'AWNJAY0M5UI70': [('B00DTPYRKC', 5),
#               ('B000051299', 5),
#               ('B000Z80ICM', 5),
#               ('B00966IREK', 5),
#               ('B001TH7GUU', 5)],
#              'A2WW57XX2UVLM6': [('B001HBIYSG', 5),
#               ('B00ATM1MHO', 4.985714285714286),
#               ('B00FJWKYP0', 4.75),
#               ('B001T9NX9Q', 4.6),
#               ('B00A0JUNWQ', 4.555555555555555)],
#              'AWNBZSEZ9P8BE': [('B0050IE1O8', 5),
#               ('B00HVT27B8', 4.914149032509368),
#               ('B00BVQXGUI', 4.75),
#               ('B003M0NURK', 4.732162039956994),
#               ('B00BUJBHGG', 4.714285714285714)],
#              'A1EQ5D5JRSW23K': [('B002WE6D44', 5),
#               ('B008X9Z8NE', 4.971398874519039),
#               ('B004AK154Q', 4.946969696969696),
#               ('B001A4HAFS', 4.904895104895105),
#               ('B00DT04I9W', 4.75)],
#              'A1GBT4UN2RW7XY': [('B00G0OYHCW', 5),
#               ('B00139JBU2', 5),
#               ('B00B4GGW5Q', 4.857142857142857),
#               ('B0014L4ZKK', 4.75),
#               ('B003WJR69E', 4.75)],
#              'A13WOT3RSXKRD5': [('B004CLYEFK', 5),
#               ('B000A0CV9S', 5),
#               ('B005LIDN00', 4.8),
#               ('B004SY5O5K', 4.8),
#               ('B000067S60', 4.714285714285714)],
#              'A20VG5W98SX99L': [('B00834SJNA', 4.660887628166367),
#               ('B001963NZI', 4.5),
#               ('B00FJWKYYG', 4.418582163768452),
#               ('B005VTIMEQ', 4.414422857359131),
#               ('B002LLJJAS', 4.345558786481872)],
#              'A1XE3M22N91451': [('B009NHAEXE', 4.795951491489064),
#               ('B003T0EYVE', 4.75),
#               ('B002ZIMEMW', 4.714285714285714),
#               ('B001NTFATI', 4.7),
#               ('B001TSMJDS', 4.571428571428571)],
#              'A4WEZJOIZIV4U': [('B00CGUMR2Q', 5),
#               ('B005HXFARS', 5),
#               ('B00BQ4F9ZA', 5),
#               ('B0007WK8KS', 5),
#               ('B00KFAGCUM', 5)],
#              'A3LWC833HQIG7J': [('B0057ODG6Y', 5),
#               ('B00187VSLY', 5),
#               ('B00IORDBPC', 4.737895489478511),
#               ('B0019EHU8G', 4.6364323342170435),
#               ('B001N85NMI', 4.444444444444445)],
#              'AWZR0O65DL2Q': [('B00005T3H5', 5),
#               ('B00005NIMJ', 4.857142857142857),
#               ('B000MT4JTC', 4.666666666666667),
#               ('B002ISXBFI', 4.6),
#               ('B00395ZQMK', 4.428571428571429)],
#              'A2IFKH3TJ10387': [('B0058SRNZ4', 5),
#               ('B001QATRCA', 4.8),
#               ('B00B7X2OTY', 4.741071428571429),
#               ('B00DOWCQB2', 4.693555341751623),
#               ('B004Q3R9AQ', 4.562355709341818)],
#              'A1W4F91DH3XPB2': [('B001XURPQI', 5),
#               ('B000JO7PIM', 5),
#               ('B0051GN9JC', 4.555555555555555),
#               ('B00DR8LA60', 4.507936507936508),
#               ('B004TPJKEY', 4.495987042329342)],
#              'A2Z1R98M2XOCEJ': [('B005QZ8BCI', 5),
#               ('B001W0XZYA', 4.8125),
#               ('B005ELBSWO', 4.625),
#               ('B006TF37H8', 4.363636363636363),
#               ('B00FG38L16', 4.185714285714286)],
#              'A35W3JQYP0M655': [('B00G500AE0', 5),
#               ('B008MWBY6W', 5),
#               ('B000P1R9QM', 5),
#               ('B001MXLD4G', 5),
#               ('B00E362W9O', 4.776452685178898)],
#              'A2WC9NFLG57W4H': [('B0034CL2ZI', 5),
#               ('B001OI2Z4Q', 5),
#               ('B005VAORH6', 5),
#               ('B0058GK55Q', 5),
#               ('B00ATM1MGA', 5)],
#              'A1EKSETIBS9ETQ': [('B0045KGZOG', 4.636363636363637),
#               ('B0099XGZXA', 4.555555555555555),
#               ('B000M17AVO', 4.538461538461538),
#               ('B0042X9LC4', 4.5),
#               ('B0042X9L6A', 4.5)],
#              'A9J4UURM4OSDW': [('B003QHXZM4', 5),
#               ('B000PEF254', 4.8),
#               ('B000OEP3F4', 4.6),
#               ('B000X1TS54', 4.5),
#               ('B0002Y5WXE', 4.285714285714286)],
#              'A29KJ32G75L7G9': [('B005ARQV6U', 5),
#               ('B007M506WS', 5),
#               ('B007WTAJTO', 4.77103612671061),
#               ('B004L9MBH6', 4.4),
#               ('B003N12TSY', 4.3)],
#              'A3CEUT263RNUDO': [('B00A2BVBTG', 5),
#               ('B004JMZPJQ', 5),
#               ('B001UI2FPE', 4.85),
# ...
#              'A1NNMOD9H36Q8E': [('B0002E3WKO', 5),
#               ('B0008D76L0', 5),
#               ('B00015GYU4', 5),
#               ('B000HGIWN4', 4.777777777777778),
#               ('B000NFIW98', 4.5)],
#              'A3R1GJY2MY8041': [('B000GHD73Y', 5),
#               ('B0056TYRMW', 4.566666666666666),
#               ('B003M2YT96', 4.4),
#               ('B0017JY5FE', 4.25),
#               ('B003FMUP3M', 4.2)],
#              'A3Q4TYJVAM4IRM': [('B00JC31SGG', 5),
#               ('B000L9OIQ2', 5),
#               ('B00L21HC7A', 4.966654041303978),
#               ('B007PJ4Q4A', 4.957142857142856),
#               ('B007R67FNA', 4.8)],
#              'AMZCZBK1EF1PV': [('B003ATZBWA', 5),
#               ('B008QUVSCA', 5),
#               ('B00EU9V3VW', 4.8),
#               ('B004CLYEH8', 4.7690958961034795),
#               ('B004CLYEE6', 4.113943398860821)],
#              'A2E1EFNIZL2FVA': [('B00JC5Y6YA', 5),
#               ('B0082E9K7U', 5),
#               ('B005A0B3FG', 5),
#               ('B005DSPLCQ', 4.921052631578948),
#               ('B006ZBWV0K', 4.833333333333333)],
#              'A3CP3J7OEGQMD5': [('B000WXSO76', 5),
#               ('B00DR9V1T0', 4.6),
#               ('B005KQ0S8S', 4.428571428571429),
#               ('B006ZP8UOW', 3.875),
#               ('B0015C30J0', 3.3333333333333335)],
#              'A186697K4XKXQL': [('B00FJRS5BA', 4.848039215686274),
#               ('B008MF3Y1W', 4.747368421052632),
#               ('B0094S35W4', 4.545454545454546),
#               ('B003FST9EC', 4.5),
#               ('B0043T7FXE', 4.427157766240476)],
#              'A11LNPG39A2ZV4': [('B004F9P2KU', 5),
#               ('B00BOHNYTW', 4.760869565217392),
#               ('B00AXVXXNC', 4.571428571428571),
#               ('B0012GQZZU', 4.333333333333333),
#               ('B00JP12170', 4.0)],
#              'APGQTZZ4ZFPHO': [('B000LRMS66', 5),
#               ('B005FUNYSA', 4.714285714285714),
#               ('B000CKVOOY', 4.666666666666667),
#               ('B000WKW69Q', 4.625),
#               ('B000M4XMGI', 4.5)],
#              'A2OTQMC69J8MUI': [('B00109Y2DQ', 5),
#               ('B000M2TAN4', 4.823529411764706),
#               ('B008OHNZI0', 4.769230769230769),
#               ('B000UXDHOI', 4.75),
#               ('B009SK57IS', 4.75)],
#              'A33SX0AD5PYD9B': [('B00JZM7TKI', 5),
#               ('B001TH7T2U', 4.933333333333334),
#               ('B000F7QRTG', 4.923076923076923),
#               ('B00HC0ZDOE', 4.875),
#               ('B003M0NT1M', 4.662679425837321)],
#              'A24QFMD1RXLJMB': [('B003Y60DZO', 5),
#               ('B0055QYJIS', 4.8),
#               ('B00007IFED', 4.666666666666667),
#               ('B002ISXBFI', 4.6),
#               ('B004VM1T5S', 4.583333333333333)],
#              'A2294LS59GC5K7': [('B003ZBZ64Q', 5),
#               ('B00A35WYBA', 5),
#               ('B002J9HBIO', 4.9335901040132875),
#               ('B00AAIPT76', 4.714285714285714),
#               ('B003YNQ6MG', 4.6)],
#              'A313H6238N589': [('B000JO7PIM', 5),
#               ('B0016OEV7C', 4.833333333333333),
#               ('B000HPV3RW', 4.774193548387097),
#               ('B001SER48S', 4.666666666666667),
#               ('B000IZDN60', 4.625)],
#              'A1XB7JGJ459ERP': [('B00E3W15P0', 5),
#               ('B000CRFOMK', 4.973260958583381),
#               ('B009SYZ8OC', 4.859319246542378),
#               ('B00005LB8P', 4.666666666666667),
#               ('B005G3066Y', 4.666666666666667)],
#              'AR6APXLK7TJU2': [('B003SX0P1A', 4.8),
#               ('B002ZIMEMW', 4.714285714285714),
#               ('B0002Y5WXE', 4.714285714285714),
#               ('B00009UTLM', 4.666666666666667),
#               ('B005TDWSF8', 4.0)],
#              'AOEAD7DPLZE53': [('B0002IWC9C', 5),
#               ('B002WE4HE2', 5),
#               ('B00077AA5Q', 5),
#               ('B000JMJWV2', 5),
#               ('B00BW6KCTU', 5)],
#              'A2D0CO1OA6DSWY': [('B004M8SWBU', 5),
#               ('B002DPUUKK', 5),
#               ('B0000A2QBP', 4.666666666666667),
#               ('B000CLNHXY', 4.466666666666667),
#               ('B004N625B4', 4.333333333333333)],
#              'A3K91X9X2ARDOK': [('B000092TT0', 5),
#               ('B00CALM17C', 5),
#               ('B00D68Y9B4', 5),
#               ('B00E98O7GC', 4.769047619047619),
#               ('B00EB7812C', 4.4)],
#              'A3SL0HA6422W4M': [('B0094S360U', 5),
#               ('B0053R0WWG', 4.818181818181818),
#               ('B003VNKKUS', 4.2),
#               ('B001UE6I0G', 4.0),
#               ('B006MA9XXM', 3.3245614035087723)],
#              'ARX7Z3NI6O0F7': [('B0000X0VCY', 5),
#               ('B0000BZL0G', 5),
#               ('B0093HKFYW', 5),
#               ('B0006ON0QQ', 5),
#               ('B000KO0GY6', 4.9772437376093395)],
#              'A296QED1MV1V0J': [('B00BOZ1Y46', 5),
#               ('B004Y1AYAC', 5),
#               ('B0045KGZOG', 5),
#               ('B004RORMF6', 5),
#               ('B00889ST2G', 4.75)],
#              'A3VBZDYGHF4NK8': [('B001PUQ7PG', 5),
#               ('B00BWHILCY', 4.714285714285714),
#               ('B004DMNT2W', 4.530018761726079),
#               ('B000JMJWV2', 4.49495840325135),
#               ('B002FYL7PG', 4.400129282482223)],
#              'A1C5WS021EL3WO': [('B007KXI2R8', 5),
#               ('B001E1Y5O6', 4.9441547693661185),
#               ('B000ENUCR4', 4.829670329670329),
#               ('B005G3066Y', 4.666666666666667),
#               ('B006Y0YZZ6', 4.6626865671641795)],
#              'A2XU6J41ZQOJ2V': [('B003L62T7W', 5),
#               ('B00029U1DK', 5),
#               ('B002PHLZE6', 4.8),
#               ('B001V9KG0I', 4.75),
#               ('B004WK3U9W', 4.538461538461538)],
#              'A22R9L5DAVYYWR': [('B001IEXU68', 5),
#               ('B000OGX5AM', 4.742951603016824),
#               ('B000JMJWV2', 4.586780496433525),
#               ('B006JWMOOI', 4.571428571428571),
#               ('B000FKP7TY', 4.333333333333333)],
#              'A24P4E3RJ6AX94': [('B00CTUIT20', 5),
#               ('B00GTGETFG', 5),
#               ('B000067RT6', 4.995812989872238),
#               ('B002BH3Z8E', 4.936704769289182),
#               ('B00081A2KY', 4.857142857142857)],
#              'A35C2IVVQR1HTK': [('B0012Y6HC8', 5),
#               ('B004K8WPUQ', 5),
#               ('B0009MZ9UA', 4.666666666666667),
#               ('B004GCJEZU', 4.257391304347826),
#               ('B007WTAJTO', 4.103005285602352)],
#              'A3GQY0TFRG0MPZ': [('B003VANO7C', 5),
#               ('B004RFBIUU', 5),
#               ('B000JE7GPY', 4.7319791831071125),
#               ('B0026ZPFCK', 4.600677183666784),
#               ('B00FFJ0HUE', 4.25)],
#              'A2SZLNSI5KOQJT': [('B003FGF2MC', 4.933333333333333),
#               ('B004CLYEH8', 4.81022685139861),
#               ('B000Q8UAWY', 4.769230769230769),
#               ('B00HWMPSF6', 4.714285714285714),
#               ('B00BVUQZZ2', 4.5)],
#              'A33PVCHCQ2BTN0': [('B0088CJT4U', 5),
#               ('B002TMRZOQ', 5),
#               ('B00BLGUKBQ', 5),
#               ('B004CLYEB4', 5),
#               ('B002Y6CJJ8', 5)],
#              'A2QNS95WGN35G9': [('B004CR7TE2', 5),
#               ('B002J9HCV0', 5),
#               ('B002TMRZOQ', 4.818181818181818),
#               ('B002KC55OM', 4.745937057716581),
#               ('B001IWOBA4', 4.5)],
#              'A10O7THJ2O20AG': [('B00E3W15P0', 5),
#               ('B000067RT6', 5),
#               ('B006W8U2MU', 5),
#               ('B001XURP7W', 5),
#               ('B000QUUFRW', 5)],
#              'A1WF4QNIE2Z3I7': [('B009NB8WR0', 5),
#               ('B00AEGRGNO', 5),
#               ('B007R1FH3K', 5),
#               ('B000AJIF4E', 5),
#               ('B007Q45EF4', 4.555555555555555)],
#              'A3S3VSXEFXBMRC': [('B0046RE21G', 5),
#               ('B001TH7GUU', 4.989878542510122),
#               ('B003XM73P2', 4.428571428571429),
#               ('B0015DYMVO', 3.9484372856238426),
#               ('B00479SVBU', 3.75)],
#              'A1HBI9BBQIG1NH': [('B00126R3P6', 4.6),
#               ('B00EN27TCI', 4.5),
#               ('B0016BVKAQ', 4.3076923076923075),
#               ('B003N2POVW', 4.222222222222222),
#               ('B0096W1P6G', 4.1520146520146515)],
#              'A1X1CEGHTHMBL1': [('B000O8JZIG', 5),
#               ('B006FLENJC', 5),
#               ('B002V88HFE', 5),
#               ('B00BB6LTI4', 5),
#               ('B002RCNX8K', 4.928571428571429)],
#              'A3T4OHEAHOJ700': [('B005BCCML2', 5),
#               ('B006A93M7I', 5),
#               ('B001U5YZ4G', 4.835501208600708),
#               ('B001FWYXD2', 4.75),
#               ('B008X9ZBVI', 4.721489253300316)],
#              'A324X7RVDAV3FT': [('B000ZMCILW', 4.875),
#               ('B0000BZL1P', 4.814814814814815),
#               ('B001BSQK8Q', 4.75),
#               ('B000VDF5RO', 4.75),
#               ('B000BYCKU8', 4.714285714285714)],
#              'A10ZBR6O8S8OCY': [('B002TLTE6O', 5),
#               ('B001N85NMI', 5),
#               ('B00DLKE8C2', 4.857142857142857),
#               ('B003YKG2XM', 4.778572372841024),
#               ('B0015HYPOO', 4.732907813091325)],
#              'A28X0LT2100RL1': [('B001TH7GUU', 5),
#               ('B00006JN3G', 5),
#               ('B002WE4HE2', 4.945201757872683),
#               ('B003CJTQJC', 4.857142857142857),
#               ('B000067RT6', 4.812436974789915)],
#              'A2SL5IW096Z2BL': [('B0021AFZOI', 5),
#               ('B002BH3Z8E', 4.6),
#               ('B00006B7DA', 4.166666666666667),
#               ('B0052TIRQI', 4.0)],
#              'A1H7Y5XKPGT0OS': [('B006ZT4VA0', 4.574193548387097),
#               ('B00212NO6W', 4.506578947368421),
#               ('B009NHWVIA', 4.408090818056332),
#               ('B00EOE4G4E', 4.400843726651702),
#               ('B0097CXWUW', 4.119874278730006)],
#              'A11EXFO14WEJM1': [('B00829THK0', 5),
#               ('B0040RWN0O', 5),
#               ('B0081FLFQE', 5),
#               ('B00565T3ZW', 4.873873873873873),
#               ('B00E87E1OM', 4.730089371906502)],
#              'ABMN74TBW5UWE': [('B007MYDWKW', 5),
#               ('B001F8SCRE', 4.934089317490696),
#               ('B002WE0QN8', 4.881481481481481),
#               ('B003547GRI', 4.333333333333333),
#               ('B0040702HU', 4.142857142857143)],
#              'A3P69DTOXII004': [('B005EJH6Z4', 4.375), ('B00CM1AANW', 3.2)],
#              'AA8RBTN3J2F5H': [('B004S4R5CK', 4.882352941176471),
#               ('B000V1PAWQ', 4.8),
#               ('B0058UUR6E', 4.526315789473684),
#               ('B007BWTOHU', 4.333333333333333),
#               ('B0018DQYQ2', 3.2)],
#              'A22I55P15NSAOX': [('B00COF7DGS', 5),
#               ('B006U1YVZ8', 5),
#               ('B003ES5ZUU', 5),
#               ('B004BDOGL6', 5),
#               ('B004DMNT2W', 5)],
#              'A1PVX61PRPVX27': [('B00609B3J2', 5),
#               ('B00B4GGW5Q', 4.857142857142857),
#               ('B003OBUJIK', 4.666666666666667),
#               ('B0019884K0', 4.0),
#               ('B004FPQJGK', 4.0)],
#              'AM0QLU79O05JR': [('B001EZYMF4', 4.5),
#               ('B0085VB8GQ', 4.285714285714286),
#               ('B004G8QO8O', 4.2),
#               ('B0055P9K38', 4.166666666666667),
#               ('B00D02AHEO', 1.833333333333333)],
#              'A3M82NO6OU1FHS': [('B008JJLW4M', 5),
#               ('B0093HKFYW', 5),
#               ('B008U69LC4', 5),
#               ('B007NZGPAY', 4.95),
#               ('B0007Y836W', 4.8)],
#              'A11P105WVK5240': [('B0002TPFTA', 5),
#               ('B00COF7DGS', 5),
#               ('B00004ZCJE', 4.452012383900929),
#               ('B005L38VPC', 4.352941176470588),
#               ('B0052YFYFK', 3.9)],
#              'A2OWR5G2OAQF7C': [('B004SCSV2U', 5),
#               ('B00BWL33H8', 4.883116883116883),
#               ('B003WJR69E', 4.75),
#               ('B00D5Q75RC', 4.730258021298467),
#               ('B00429N18S', 4.6807764187458725)],
#              'A2Q7OJTVPIO2XH': [('B0000BZL1P', 5),
#               ('B0058G40O8', 5),
#               ('B005HMKKH4', 4.942521994134897),
#               ('B0043WJRRS', 4.888888888888889),
#               ('B005KEL4NI', 4.75)],
#              'A35HOUWHAYZZN6': [('B00834SJSK', 5),
#               ('B005A0B7CA', 4.824675324675325),
#               ('B005BCCML2', 4.75),
#               ('B003HIXP9K', 4.75),
#               ('B004T9RR6I', 4.361547603994187)],
#              'A1USYP4AXF5I1D': [('B002N2EHVQ', 4.8),
#               ('B003WV5DJC', 4.714285714285714),
#               ('B002V88HFE', 4.6438356164383565),
#               ('B003WOL4VK', 4.5),
#               ('B0043VE28S', 4.444444444444445)],
#              'A1PL7QILVQV3IF': [('B0010Z28XG', 5),
#               ('B00275EVAQ', 5),
#               ('B00029U1DK', 4.966386554621849),
#               ('B00140DBRY', 4.8),
#               ('B003VANO7C', 4.777777777777778)],
#              'A5QDZEOIMQ4LW': [('B004ZNA3UA', 5),
#               ('B0015YRMXI', 4.714285714285714),
#               ('B003QKBVYK', 4.571428571428571),
#               ('B00CMEN95U', 4.0)],
#              'A33152QEGO2MZN': [('B000IJY8DS', 5),
#               ('B007BJHETS', 4.833333333333334),
#               ('B004AZ38Z0', 4.5),
#               ('B001WB02Z4', 4.5),
#               ('B000A6PPOK', 3.7)],
#              'A2BX8DDQGCCG2J': [('B00746W3HG', 4.888888888888888),
#               ('B000067RVL', 4.875),
#               ('B0011U65F2', 4.8125),
#               ('B001FA1O0O', 4.777855665127821),
#               ('B0097BEF1S', 4.744107744107744)],
#              'A95PWI4S6WHGL': [('B00F3F0EIU', 4.828723181765096),
#               ('B001TI9F8U', 4.333333333333333),
#               ('B000K4V4X8', 3.0)],
#              'A3JV071KO43Q5X': [('B00DSUTVK4', 5),
#               ('B004QK7HI8', 4.189820515285316),
#               ('B004T9RR6I', 4.150504784092051),
#               ('B00ARB5FLQ', 3.880727762803234),
#               ('B002HHLOWC', 3.6666666666666665)],
#              'A28N2AWOVO2PB': [('B006A93M7I', 5),
#               ('B00DTPYQBM', 5),
#               ('B002S0O7LI', 5),
#               ('B006DEBYWU', 5),
#               ('B004N625B4', 4.976190476190476)],
#              'A14NA0W8ESGDSI': [('B0034CL2ZI', 5),
#               ('B00C9TECFO', 5),
#               ('B00IQ0SE22', 5),
#               ('B004ELA0SS', 5),
#               ('B002DUCMQU', 5)],
#              'A377LPVLLAI42D': [('B000BWACX2', 5),
#               ('B003SGCO3E', 4.888888888888889),
#               ('B004JWA70I', 4.111111111111111),
#               ('B0015TJNEY', 3.6666666666666665),
#               ('B000JVCPEY', 2.6)],
#              'A2MOD50IHEDH3G': [('B001IEXU68', 5),
#               ('B003A7CDY6', 5),
#               ('B0044XU43C', 5),
#               ('B000N99BBC', 4.950986551645482),
#               ('B006EKIQYM', 4.85632183908046)],
#              'A1CMWB7AWQUQH4': [('B00505EZZ6', 5),
#               ('B000VE2RP6', 4.571428571428571),
#               ('B009ZIILLI', 3.7948717948717947),
#               ('B005CPGHAA', 3.6666666666666665)],
#              'A3NGOG8Z78AZSD': [('B004ELA0SS', 4.9),
#               ('B003ICXCCK', 4.666666666666667),
#               ('B002J9HBSE', 4.571428571428571),
#               ('B0056VOM2U', 4.333333333333333),
#               ('B00002EQCW', 4.2)],
#              'A2FHTXLKY1XJDB': [('B002OOWB3O', 4.666666666666667),
#               ('B000UO6C5S', 4.636363636363637),
#               ('B001AHALEC', 4.571428571428571),
#               ('B002IJ95ZM', 4.428571428571429),
#               ('B008CXTX7S', 4.2)],
#              'A1UNJ46NSB352E': [('B00825BZUY', 5),
#               ('B00D5Q75RC', 5),
#               ('B003MVZ60S', 4.625),
#               ('B00ISIG690', 4.428571428571429),
#               ('B00I053I5G', 4.4)],
#              'A1V5TRJXTI6F01': [('B0037H8AB4', 5),
#               ('B00A83I8G2', 5),
#               ('B001UGMTKC', 4.75),
#               ('B003DZ165W', 4.388888888888889),
#               ('B004I5BUSO', 4.333333333333333)],
#              'A2RIXSMGE9VIBG': [('B000JV9LUK', 5),
#               ('B006JWMOOI', 4.571428571428571),
#               ('B0097252UK', 3.857142857142857)],
#              'A2MCRCK1V61FWQ': [('B001NJ0D0Y', 4.555555555555555),
#               ('B009W8YQ6K', 4.166666666666667),
#               ('B0009ZBRS0', 3.5714285714285716)],
#              'A2EMUM49CE0JV4': [('B00004ZCDD', 5),
#               ('B000QUUFRW', 5),
#               ('B000Q85WRC', 5),
#               ('B0058UUR6E', 4.526315789473684),
#               ('B000NB05MO', 4.5)],
#              ...})

# %%
uid= "A2EMUM49CE0JV4"
print(top_n[uid])
# Out:
# [('B00004ZCDD', 5), ('B000QUUFRW', 5), ('B000Q85WRC', 5), ('B0058UUR6E', 4.526315789473684), ('B000NB05MO', 4.5)]
